# %% [markdown]
# <h1 style="color:rgb(0,120,170)">Artificial Intelligence in Life Sciences</h1>
# <h2 style="color:rgb(0,120,170)">Evaluation and assessment of generative models</h2>

# %% [markdown]
# #Importing Libraries

# %%
# !pip install rdkit
# !pip install fire 
# !pip install fcd

# Neural-based generator of organic compounds
import functools
import fire
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.functional import one_hot
from tqdm import tqdm
from rdkit import RDLogger
from rdkit import Chem


import os
import pandas as pd
import numpy as np
import pickle
import rdkit

# Ignore some warnings from RDKIT and keras
from rdkit import RDLogger  
RDLogger.DisableLog('rdApp.*') 

import warnings
warnings.filterwarnings("ignore")

# Load methods from the FCD library
from fcd import get_fcd, load_ref_model, canonical_smiles, get_predictions, calculate_frechet_distance

np.random.seed(1234)

print("RDKit: ", rdkit.__version__)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rdkit
#   Downloading rdkit-2023.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 38.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.22.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (8.4.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.3.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire) (2.3.0)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116932 sha256=c2d145b93e2d47f90a69e2052c78b503a53d7076e7c8bc04ee0b41599dc05672
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# Installing collected packages: fire
# Successfully installed fire-0.5.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fcd
#   Downloading FCD-1.1-py3-none-any.whl (53.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 MB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from fcd) (2.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fcd) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from fcd) (1.10.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from fcd) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (1.54.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (0.4.10)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->fcd) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->fcd) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow->fcd) (0.1.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->fcd) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->fcd) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->fcd) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->fcd) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->fcd) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->fcd) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->fcd) (2.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->fcd) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->fcd) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->fcd) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->fcd) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->fcd) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->fcd) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->fcd) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->fcd) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow->fcd) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->fcd) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->fcd) (3.2.2)
# Installing collected packages: fcd
# Successfully installed fcd-1.1
# RDKit:  2023.03.1

# %% [markdown]
# # GRU model

# %%
__special__ = {0: "<PAD>", 1: "<BOS>", 2: "<EOS>"}
RDLogger.DisableLog('rdApp.*')

class SmilesProvider(torch.utils.data.DataLoader):
    def __init__(self,file,total=130):
        self.total = total
        self.smiles = open(file, 'r').read().split("\n")[:-1]
        tokens = functools.reduce(lambda acc,s: acc.union(set(s)), self.smiles ,set())
        self.vocsize = len(tokens) + len(__special__)
        self.index2token = dict(enumerate(tokens,start=3))
        self.index2token.update(__special__)
        self.token2index = {v:k for k,v in self.index2token.items()}
        self.ints = [torch.LongTensor([self.token2index[s] for s in line]) for line in tqdm(self.smiles,"Preparing of a dataset")]

    def decode(self,indexes):
        return "".join([self.index2token[index] for index in indexes if index not in __special__])

    def __getitem__(self,i):
        special_added = torch.cat((torch.LongTensor([self.token2index['<BOS>']])
                                   ,self.ints[i],torch.LongTensor([self.token2index['<EOS>']]),
                                   torch.LongTensor([self.token2index["<PAD>"]]*(self.total-len(self.ints[i])-2))),dim=0)
        return one_hot(special_added,self.vocsize).float(),special_added

    def __len__(self):
        return len(self.smiles)

class SimpleGRU(nn.Module):

    def __init__(self, vocsize,device,hidden_size=512,num_layers=3):
        super().__init__()
        self.device = device
        self.vocsize = vocsize
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(vocsize,hidden_size,bidirectional=False,batch_first=True,num_layers=num_layers)
        self.linear = nn.Linear(hidden_size,vocsize)


    def forward(self,x):
        output = self.gru(x)[0]
        final = self.linear(output)
        return final

    def sample(self,batch_size=128,max_len=130):
        bos_token = [k for k,v in __special__.items() if v == "<BOS>"][0]
        x = torch.LongTensor([bos_token]*batch_size)
        h = torch.zeros((self.num_layers,batch_size,self.hidden_size)).to(self.device)
        accumulator = torch.zeros(batch_size,max_len)
        for i in range(max_len):
            x = one_hot(x, self.vocsize).float().unsqueeze(1).to(self.device)
            output,h = self.gru(x,h)
            next = F.softmax(self.linear(output).squeeze(1),dim=1)
            x = torch.multinomial(next,num_samples=1,replacement=True).squeeze(1)
            accumulator[:,i] = x
        return accumulator

def generate(file='genmodel_.pt', batch_size=64):
    box = torch.load(file)
    model, tokenizer = box['model'], box['tokenizer']
    model.eval()
    res = model.sample(batch_size)
    correct = 0
    for i in range(res.size(0)):
        smiles = "".join([tokenizer[index] for index in res[i].tolist() if index not in __special__])
        print(smiles)
        correct = correct + 1 if Chem.MolFromSmiles(smiles) else correct

    print("% of correct molecules is {:4.2f}".format(correct / float(batch_size) * 100))



def train(file='/content/smiles_train-2.txt', batch_size=256, learning_rate=0.001, n_epochs=2, device='cuda'):
    device = device if torch.cuda.is_available() else 'cpu'
    dataset = SmilesProvider(file)
    model = SimpleGRU(dataset.vocsize, device=device).to(device)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    loss_function = nn.CrossEntropyLoss()
    model.train()
    for epoch in range(1, n_epochs + 1):
        for iteration, (batch, target) in enumerate(tqdm(dataloader, 'Training')):
            batch, target = batch.to(device), target.to(device)
            out = model(batch)
            out = out.transpose(2, 1)
            loss = loss_function(out[:, :, :-1], target[:, 1:])
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    model.device = 'cpu'
    torch.save({'tokenizer': dataset.index2token, 'model': model.cpu()}, "genmodel.pt")


#if __name__ == '__main__':
    #fire.Fire()
# Out:
# Requirement already satisfied: rdkit in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (2023.3.1)
# Requirement already satisfied: numpy in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from rdkit) (1.23.5)
# Requirement already satisfied: Pillow in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from rdkit) (9.4.0)
# Requirement already satisfied: fire in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: termcolor in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from fire) (2.3.0)
# Requirement already satisfied: six in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from fire) (1.16.0)

# %% [markdown]
# #Train model

# %%
if __name__ == '__main__':
    train()

# %% [markdown]
# #Generate some new molecules

# %%
for _ in range(25000):
    generate(file='genmodel.pt', batch_size=1)
# Out:
# CC(=O)c1ccccc1CN1C(=O)c2ccc(C(=O)Nc3cccc(C(=O)O)c3)cc2CC1C
# % of correct molecules is 100.00
# c1cc(-c2nnc(-c3ccccc3Nc3nncs3)n2-c2ccccc2)cc1
# % of correct molecules is 0.00
# Cc1cccc(C(=O)C=Cc2sccc2-c2nnn[nH]2)c1
# % of correct molecules is 100.00
# COc1ccc(NC(=O)c2cccc(OC(=O)c3cccc(OC)c3)c2)cc1
# % of correct molecules is 100.00
# S=CNSc1nc2ccccc2o1
# % of correct molecules is 100.00
# Cn1c(=O)c2ccc3c(c21)C(=O)c1ccccc1-3
# % of correct molecules is 100.00
# CCCC(CN1CC=CCC1)NS(=O)(=O)c1ccc(-c2ccccc2)cc1
# % of correct molecules is 100.00
# Cc1cccc(NNC(=O)C(N)Cc2ccc(OCCCCNc3ccc(Cl)cc3C)o2)c1
# % of correct molecules is 100.00
# CC(=O)CCn1nc(C)cc1C(=O)NCc1cccs1
# % of correct molecules is 100.00
# CCc1ccc(CNC(=O)CC(=O)N=C(N)N)cc1
# % of correct molecules is 100.00
# Oc1cc2c(cc1O)Oc1cccc(OCCNc3c5c(nc5ccccc25)CCC35)c1
# % of correct molecules is 100.00
# Cc1sc2ncn(Cc3ccccc3)c2c1CN1CCN(c2ccccc2)CC1
# % of correct molecules is 100.00
# CCc1cc2ncc(C=Cc3ccc(O)cc3)sc2c1C
# % of correct molecules is 100.00
# CC12CCC3C(CCCC3)CC1C(NC(=O)c1cccs1)C(=O)N2C(CC=C1C2CCS13C)C(C)(C)C
# % of correct molecules is 0.00
# COCCc1ccc(-c2nc(C)c3ccccc3c2-c2ccc(NC(=O)c3ccc(C(=O)Nc4ccc([N+](=O)[O-])cc4)o3)nc2)c([N+](=O)[O-])c1
# % of correct molecules is 100.00
# CN=C(S)N(CCO)S(=O)(=O)c1ccc(Cl)cc1
# % of correct molecules is 100.00
# COc1ccc(C=NNC(=O)c2nnn(-c3ccc(OC)cc3)n2)cc1
# % of correct molecules is 100.00
# N#Cc1cc(-c2ccc(Cc3cscn3)cc2)ccc1=NO
# % of correct molecules is 0.00
# Cc1nc2sccc2n1Cc1ccccc1
# % of correct molecules is 100.00
# Cc1ccc(C)c(CSc2ccc(C=O)cc2O)n1
# % of correct molecules is 100.00
# CC(=CC(=O)Nc1nc(-c2ccccc2)sc1C)N1C(=O)NC(c2ccccc2)=C1c1ccc(OCc2ccccc2)cc1
# % of correct molecules is 100.00
# CC(=NOC(=O)c1ccc2c(c1)OCO2)CC(=O)O
# % of correct molecules is 100.00
# Cc1ccc(S(=O)(=O)NC(=O)Nc2ccc(-c3cn4nnc(C(=O)N4CCCC5)n3)cc2)s1
# % of correct molecules is 0.00
# CS(=O)(=O)c1ccc(CC2CCN(CC(=O)c3ccccc3Cl)C(=S)N2)o1
# % of correct molecules is 100.00
# Cc1ccccc1NC(=O)Cc1cccc2ccccc12
# % of correct molecules is 100.00
# CCC(c1n[nH]c2ncnc(NNC(=O)CCl)cc12)N(Cc1ccccc1)S(C)(=O)=O
# % of correct molecules is 0.00
# CN(C)CCN(C)CCCc1ccc(SCc2ccccc2)cc1
# % of correct molecules is 100.00
# CC1=C(Cc2nc3ccccc3[nH]2)n2ncnc2N1
# % of correct molecules is 100.00
# Cc1ccc(C(=O)NCCCNC2CC2)cc1-c1ccc(C2=NN(CCC(C)C)CC2)cc1
# % of correct molecules is 100.00
# C=C1CCC(c2nccc(OC)c2Cl)=N1
# % of correct molecules is 100.00
# CCCCc1ncc2c(=O)n(Cc3ccc(C(=O)N(CC)CC)C(C)c4ccccc4)cc3o1
# % of correct molecules is 0.00
# Oc1cc(COCc2cccc(OCc3ccccc3)c2)cc2ncccc21
# % of correct molecules is 100.00
# CN1CC2CN(C3CCCCC3)C(=O)C2(CC(=O)Nc2ccc(C3CN(C)CC3)c3[nH]cnc23)C1
# % of correct molecules is 100.00
# CCCC(=O)Nc1ccc(Oc2cccc(CN(C)C)c2)cc1
# % of correct molecules is 100.00
# Cc1cccc(-c2nc(N)c3nn(Cc4ccccc4Cl)nc3n2)c1
# % of correct molecules is 100.00
# Nc1ncnc2cc(-c3ccc(OCCCCC(C)(C)O)cc3)ncc12
# % of correct molecules is 100.00
# CNC(=O)C(C)c1ccc(Cl)cc1
# % of correct molecules is 100.00
# Cc1ncc(-n2ncc(N3CCN(c4ccc(C(=O)OC(C)(C)C)cc4)-3)nc2N2CCCCC2)s1
# % of correct molecules is 0.00
# CC(Oc1ccc(Br)cc1)Cc1ccccc1
# % of correct molecules is 100.00
# O=C(CCCCC(=O)NCc1ccccc1Oc1ccccc1)(c1ccccc1)c1ccccc1
# % of correct molecules is 0.00
# CCCCCCn1c(=O)c2c(nc(-c3ccc(C(=O)N(C)C)nc3)nn2)c2cc(Cl)ccc2n1
# % of correct molecules is 0.00
# c1ccc(OCC2CN=C(Cc3ccccc3OCc3cscn3)C2)cc1
# % of correct molecules is 100.00
# O=C(Cn1c(=O)n(C2CC(=O)C(O)=NC2=O)nn1)c1ccc(Br)cc1
# % of correct molecules is 100.00
# O=P(O)(O)P1(=O)NC(C[Se]c2ccc(Cl)cc2)C(O)C(O)C1O
# % of correct molecules is 100.00
# COC(=O)CC(C)(C)CCc1ccc(OCCNC2(O)C(=O)NC(C)=O)cc1
# % of correct molecules is 0.00
# O=C(NCc1ccc(-c2ccc(C=Cc3ccccc3)cc2)cc1)c1ccccc1
# % of correct molecules is 100.00
# CCOC(=O)Nc1ccc(Nc2ncnc3oc(C)cc23)cc1
# % of correct molecules is 100.00
# COC(=O)c1c(O)c2ccccc2n(-c2ccccc2Cl)c1=O
# % of correct molecules is 100.00
# CN(C)c1nc(N(C)c2cccc3cccnc23)nc(-c2ccccc2Br)n1
# % of correct molecules is 100.00
# CC(C)(O)C(N)c1ccc(-c2ccsc2)cn1
# % of correct molecules is 100.00
# O=C(Nc1cccc2nc(-c3ccc(Br)cc3)n1-c1ccccc1-2)c1ccccc1
# % of correct molecules is 0.00
# COC1C2OC3C=C4CC=CC(O)C4(C)C3CCC12C
# % of correct molecules is 100.00
# CC(=O)N1C(c2cnc(=O)oc2C)-c2coc(n2)CC1C(=O)NC(C(=O)OC(C)(C)C)C(=O)C1(O)CCCC1
# % of correct molecules is 100.00
# CC1CCC2C(C)N(C)C(=O)C21
# % of correct molecules is 100.00
# COCC1C2C(O)(CN3C(=O)NC3=O)C(C)C(Oc3ccc(C(C)N(C)C)cc3)OC(=O)C21
# % of correct molecules is 100.00
# CCCCCn1nc(-c2ccc(OC(CCNS(=O)(=O)Cc3ccccc3)c3cc(OC)c(OC)c(OC)c3C)cc2)c(OC)c1C
# % of correct molecules is 100.00
# O=C(Nc1cccc(Sc2nc(C3CC3c3ccccc3C(=O)NC3CCC(C(O)c4ncccc4C4CCOCC4)C3)c(=O)[nH]c2=O)c1)c1ccccc1CCN1CCCCC1
# % of correct molecules is 0.00
# Cc1[nH]c2ccccc2c1-n1cnc2c(OCc3ccc(Cl)cc3)cccc21
# % of correct molecules is 100.00
# Cc1cc(NC(=O)NC(CCC(=O)NC(CC(C)=O)C(C)C)C(=O)N(CC)CC)c2ccc3ccccc3c12
# % of correct molecules is 0.00
# CCN1CCN(c2ccc(-c3cn(-c4ccnc5cccnc45)nn3)cc2)CC1c1ccc(-c2ccccn2)cc1
# % of correct molecules is 100.00
# C=CC1(C)CC(OC(=O)CC(=O)NCCC(C)C)CCC1
# % of correct molecules is 100.00
# COC(=O)c1ccc2c(N1CCN(C(=O)c4ccccc4)CC3CC)cc(OC)c1OCCCCCCN
# % of correct molecules is 0.00
# O=C(O)CCC(NC(=O)Nc1ccc(OCC2CC2)cc1)C(=O)NC1CCNCC1
# % of correct molecules is 100.00
# CSCCC(NS(=O)(=O)CC(=O)NC1C(=O)N=C(N)N)C1(C)C(=O)NC(C)C(=O)OC(C)C(=O)O
# % of correct molecules is 100.00
# CC(Nc1ccc(-c2ccnc3[nH]cc(C#N)c23)c(C2C(CO)C(O)CC2)n1)C(=O)NCC(=O)O
# % of correct molecules is 100.00
# COc1ccc(C)c(C=Nc2nc3ccccc3nc2NS(=O)(=O)c2ccccc2)c1C
# % of correct molecules is 100.00
# O=Cc1c(Oc2ccccc2)c(=O)[nH]c2ccc(=O)ccc12
# % of correct molecules is 100.00
# CC(NC(=O)c1cc([N+](=O)[O-])c([N+](=O)[O-])c1)C(=O)NC(CC(C)C)C(=O)NC(C=Cc1ccccc1Cl)C(C)(C)C
# % of correct molecules is 0.00
# COCCn1c(C)c(C(=O)CCN2C(=O)CSc2sccc2-2)cc1-c1ccccc1
# % of correct molecules is 0.00
# CN(C)c1c2c(nc3ccccc13)CCC2
# % of correct molecules is 100.00
# O=C1C(=CC=c2ccc(Cl)c(Cl)c2)=NOC1(c1ccccc1)c1ccccc1
# % of correct molecules is 0.00
# COC(=O)c1ncccc1NC(=O)Nc1cc(N2CCOCC2)n2nc(-c3cnccn3)nc12
# % of correct molecules is 0.00
# NC(CCc1c[nH]c2ccccc12)C(=O)NC(CCC(=O)O)C(=O)O
# % of correct molecules is 100.00
# CNC(=O)C1CCCNC(=O)C(CC(=O)NCc2ccccc2)OO1
# % of correct molecules is 100.00
# Cc1cc(c2c3c(cc4ccccc43)n(CCCO)nn2)ccc1=O
# % of correct molecules is 0.00
# Cc1nn(CC(=O)Nc2sccc2C)c2nc(C)nc(NC(C)C)c2n1
# % of correct molecules is 0.00
# COc1cccc(-c2c(-c3cnn(C)c3)nc3sc4[nH]c5c(c3c23)CCCCC3)c1
# % of correct molecules is 0.00
# CC(C)C(NC(=O)CCCC#N)C(=O)NC(CCC(=O)OCC(N)=O)C(=O)N1CCCC1C(=O)NC(Cc1ccc(Cl)cc1)C(=O)Nc1ccccc1
# % of correct molecules is 100.00
# Cc1c(Cc2cccc(Cc3ccccc3)c2)c2cccc(C)n12
# % of correct molecules is 0.00
# COc1cc(CNc2ccnc4cc(C#N)ccc23)ccc1OC2C(=O)O
# % of correct molecules is 0.00
# O=C(O)Cc1c(-c2ccco2)sc2ccc(Cl)cc12
# % of correct molecules is 100.00
# O=C(COC(N)=S)c1ccc(Cl)s1
# % of correct molecules is 100.00
# COc1ccccc1C1NC(=O)C(C)C(C)CN(CC(=O)NC(C)C)C1
# % of correct molecules is 100.00
# Cc1ccc(C(=O)OCC(=O)C=Cc2ccccc2)cc1
# % of correct molecules is 100.00
# COC1=C2C=C(C)C(=O)CCC2C=C(C)CC1O
# % of correct molecules is 100.00
# Cc1cc(COc2ccccc2-c2nc(-c3ccc(C(N)=O)cc3)oc2C(=O)O)s1
# % of correct molecules is 0.00
# COc1ccc(-c2cc(C=C3SC(=S)N=N(Cc4ccc(Cl)cc4)CC(=O)N3C)cc2)cc1
# % of correct molecules is 0.00
# CN(C)C(=O)c1ccc(S(=O)(=O)Nc2cccc(C(=S)N3CCCC3)c2)c(Cl)c1
# % of correct molecules is 100.00
# CCCCn1nc2c(c1NC(=O)C=Cc1ccc3c(c2)OCO3)C=C1N(C)C
# % of correct molecules is 100.00
# Cc1sc2ncn(-c3cc(S(C)(=O)=O)cc(C(=O)O)c3Br)c2c1-c1ccc(O)cc1
# % of correct molecules is 100.00
# NCC(=O)Nc1ccc(-c2ccc3c(c2)nc(Nc2ccc(C4CC4)cn2)cn1)CCNSC2
# % of correct molecules is 0.00
# Cc1cc2n(cc1C)SCCc1cc2c(cc1c2-n1c(C)cn3cccc13)CC2
# % of correct molecules is 100.00
# CCc1nccn1Cc1cn(C2CC2C)nc1-c1c(N)ncc2ccccc12
# % of correct molecules is 100.00
# O=C1C2=C(CC(c3ccccc3OCc3ccccc3)O2)SC1=Cc1cccc(O)c1
# % of correct molecules is 100.00
# CCC(CC(O)C(CC1=CCCOC1)=NOC(=O)c1cccnc1)C(=O)NCC(O)COc1ccc(CC(c2ccc(CO)o2)c2ccc(Cl)cc2)cc1
# % of correct molecules is 100.00
# O=C(O)C(CCCc1ccccc1Cl)N1CCCCC1
# % of correct molecules is 100.00
# Cc1nc(-c2ccc(C)cc2)sc1-c1ccn(CCO)c1
# % of correct molecules is 100.00
# CS(=O)(=O)c1ccc(Cl)cc1NC(=O)CSc1nnc(-c2ccc(Br)cc2)s1
# % of correct molecules is 100.00
# COc1cc2c3c(oc4ccccc4c3=O)c2cc1OC
# % of correct molecules is 100.00
# O=C1c2ccccc2C2c3ccc(O)cc3C(C2C(C(C)(C)Cc2ccccc2)C1O)NC(=O)CCCc1ccccc1
# % of correct molecules is 100.00
# Brc1ccccc1-c1nnc(S)n1Cc1ccccc1
# % of correct molecules is 100.00
# Cc1cc(C(=O)C(=O)NC(=Nc2ccccc2)S(=O)(=O)c2cccs2)s1
# % of correct molecules is 0.00
# CSc1cc2ncnc(NC3CCC(C)N3)nn2c1cnn2-c1cnccn1
# % of correct molecules is 0.00
# Cc1ccc(S(=O)(=O)N2CCC(c3ccccc3)CC2)c(S(C)(=O)=O)c1
# % of correct molecules is 100.00
# NCCN1CCCC1CNCc1c[nH]c2ccc(-c3cc[nH]c3)cc12
# % of correct molecules is 100.00
# CSc1cccc(Br)c1C
# % of correct molecules is 100.00
# Cn1c(O)nc2cnc(NCO)nc21
# % of correct molecules is 100.00
# Cc1ccc(NC(=O)c2cc3cc(Br)cc(Br)c3[nH]2)cc1
# % of correct molecules is 100.00
# CCN(CC)(CC(=O)N1CCSCC1)c1c(C)noc1C
# % of correct molecules is 0.00
# CON=C(C)C(=O)CCC(=O)Nc1cc(CN=Cc2cccc(OC)c2)c2cc(OCc3ccccc3Cl)sc2n1
# % of correct molecules is 100.00
# CC1(C)CC(=O)C=CC1=CC=CCC=CCCCCCCCC
# % of correct molecules is 100.00
# COc1ccc(-c2cncc(CNC3CCC(N)n3)nn2)cc1
# % of correct molecules is 0.00
# O=C(O)c1ccc(OP(=O)(O)O)cc1
# % of correct molecules is 100.00
# O=c1c(-c2cccc3c(c2)CCN(C(=O)Nc2ccccc2S(=O)(=O)O)C(=O)O)ccc2c1CCc1cncn1-2
# % of correct molecules is 0.00
# O=C(CCS(=O)(=O)c1cccc([N+](=O)[O-])c1)C(S)=Nc1ccccn1
# % of correct molecules is 100.00
# O=C(Cc1ccccc1)NC(CCCCNCc1cccc2ccccc12)C(=O)NCCc1ccccc1
# % of correct molecules is 100.00
# Cc1cc(NC(=O)C(c2ccccc2)c2cccnc2)no1
# % of correct molecules is 100.00
# CCc1cc([N+](=O)[O-])c(Nc2cccc3cc(N)nc(N)c23)c(C)c1c
# % of correct molecules is 0.00
# CCn1cc(CSc2nnc(-c3ccc(Cl)cc3)n2C2=NCCS2)n1
# % of correct molecules is 0.00
# Cc1cc(=O)oc2c1c(C)nn2Cc1cccc(Br)c1
# % of correct molecules is 100.00
# CCn1c2ncccc2c2ccccc21
# % of correct molecules is 100.00
# CCc1nc(NCCCCCCC(=O)N(C)C)ns1
# % of correct molecules is 100.00
# CC(=O)N(C)c1cc2ncnc(NS(=O)(=O)Nc3cccc(S(=O)(=O)N(C)C)c3)c2cc1-c1cc(OC)cc(OC)c1OC
# % of correct molecules is 100.00
# S=C(NC1CCC(O)C(O)C1O)c1cccc(CN(CC(=O)O)CCCl)c1
# % of correct molecules is 100.00
# O=C1OCC(C1(N=C1C(=O)N(Cc2cccc[n+]1[O-])C(=O)NCc1ccccc1)CCN2CCCCCCOc1ccccc1
# % of correct molecules is 0.00
# C=CCc1c(O)ccc2c3c(c4sc(N5CC(O)CC(N)=O)cc4cc1c3C4)CC(CC1CC1C)C2
# % of correct molecules is 0.00
# CC(=O)N1C(N(CCN2CCOC(C(=O)c3ccccc3OCc3ccccc3)CC2)C(CC(C)C)C(=O)O)CS(=O)(=O)C1)c1ccc(OC(C)=O)cc1
# % of correct molecules is 0.00
# COc1cc2c(cc1OC)C1(n3ccc(=O)n3C)CCN(C(=O)C3CCCO3)CC21
# % of correct molecules is 100.00
# O=C1CN(C(=O)N2CCc3ccc(c4)cc3S(=O)(=O)c2ccccc2N(CCN2CCOCC2)Cc2ccccc2)CC1
# % of correct molecules is 0.00
# OCC1CC(c2ccc(Oc3nccnc3)cc2)CC1NC(=O)c1cccc(S(=O)(=O)O)c1
# % of correct molecules is 100.00
# Cc1ccc(C2=CC(n3ccnc3C)CC(CO)Oc3ccccc32)cc1
# % of correct molecules is 100.00
# CN(C)Cc1ccc([N+](=O)[O-])cc1OC
# % of correct molecules is 100.00
# COc1ccc(NC(=O)c2ccoc2C)cc1
# % of correct molecules is 100.00
# CCOC(=O)C12OCOC1c1cc(ccc1OC)-c1ccc(OC)c(OCC=C3CCCC3)c2O1
# % of correct molecules is 100.00
# Cc1conc1-c1nc(C)c2c(c1Cl)OC12CC3CN(CC(C)(C)CNC2=O)C1=O
# % of correct molecules is 0.00
# COc1cc(C=CC(=O)O)cc(OCOC(=O)c2ccc(-c3nn[nH]n3)cc2)C(C)(C)c1=O
# % of correct molecules is 0.00
# CC(C)C(=O)c1ccc(C=CC(=O)NC2CCCCC2)cc1
# % of correct molecules is 100.00
# Brc1ccc(C=c2snnn2)c(C#N)c1
# % of correct molecules is 0.00
# CCN(CC)CCOc1cc(OC)c2cc(-c3ccccc3OC)ncc2c1
# % of correct molecules is 100.00
# CC(=O)NC(C(=O)NCC[N+](C)(C)C(=O)NCC(O)CNC(=O)CCc1ccc(-c2ccccc2-c2nn[nH]n2)C2CC3CCC(C(C)=O)C2O1)c1ccccc1
# % of correct molecules is 0.00
# CCc1ncn2c1C(c1ccc(Cl)cc1)C2C=CC(=O)N(C)C
# % of correct molecules is 100.00
# CCCCCCCCCCCCCC(=O)C=CC=CC(=O)NCc1cccnc1
# % of correct molecules is 100.00
# CCCc1nc2nc3c(cc1C3=Cc4ccccc4CO3)Oc1ccccc1N3
# % of correct molecules is 0.00
# O=C(O)c1ccc2c(c1)C(=O)c1cc-cc1Sc1ccn(-c3ccc(Cl)cc3)c(Cl)c12
# % of correct molecules is 0.00
# O=C(CSc1ccccc1)NN=Cc1ccc(CNC(=O)c2cccc(Br)c2)cc1
# % of correct molecules is 100.00
# CCNS(=O)(=O)c1ccc2nc(C3CC(Cn4ccnc5)C3)nc2c1
# % of correct molecules is 0.00
# CC(=O)Nc1cccc(N)c1C(=O)NC(C)c1ccc2ccccn2c1=O
# % of correct molecules is 100.00
# CC=CC#CC(=O)NC(CCCC)Cc1ccccc1
# % of correct molecules is 100.00
# CC(CCC(O)CP(=O)(O)O)CP(=O)(O)O
# % of correct molecules is 100.00
# CC(=O)OC1CC=CC(C)C2OC3CC(O)C2CS1
# % of correct molecules is 0.00
# Cc1ccncc1-c1cccc(O)c1
# % of correct molecules is 100.00
# CCOc1ccc2c(c1)sc(=O)n2CC
# % of correct molecules is 100.00
# COc1ccc(-c2cnc(Cn3nnc4ccc(OC)cc43)cc2C#N)c(Br)c1
# % of correct molecules is 100.00
# CC(NCc1ccccc1C(=O)NCCC1CCCO1)c1ccccc1
# % of correct molecules is 100.00
# CC1C(=O)Nc2ccc(S(=O)(=O)NC(=O)C(=NNO)c3cccc(Cl)c3)cc2N1C(=O)N1CCC(c2ccccn2)CC1
# % of correct molecules is 100.00
# CCCCCCCCC=CCCCCCCCCCCCc1nc(-c2ccccc2)n(C)c1=O
# % of correct molecules is 0.00
# O=C1Nc2ccc(Brc3ccccc3)cc2C1=Cc1ccsc1
# % of correct molecules is 0.00
# Cc1nnc(CN2CCCN(C(=O)C3CCCC3)CC2)n1
# % of correct molecules is 0.00
# NC(=S)NNc1ccc(-c2ccccc2Cl)cc1
# % of correct molecules is 100.00
# O=C(Nc1ccccc1)c1cccs1
# % of correct molecules is 100.00
# CC1CCC(C2)C(c3ccc4c(c3)OCO4)CN(C(=O)c3ccccc3)C2C1
# % of correct molecules is 100.00
# Cc1ccc(CNc2nccnc2[S+]2c3cccc(Cl)c3C2=O)c2cc(Br)ccc12
# % of correct molecules is 100.00
# c1ccc(Cn2c(CN3CCCC3)nc3c2CCCN3CCCN(C(=O)c2ccccc2Cl)CC3)cc1
# % of correct molecules is 0.00
# CCOC(=O)c1sc2ccccc2c1NC(=O)c1ccon1
# % of correct molecules is 100.00
# COc1ccc(C=Cc2ccc3ncccc3c2)cc1OC
# % of correct molecules is 100.00
# COc1cc(C=CC(=O)NCCCSc2nc3cccc(OCc4c(C)cc(C)c(I)c4)c(C(C)C)c3oc2=O)ccc1O
# % of correct molecules is 0.00
# COC(=O)c1ccc(Br)cc1S(=O)(=O)Nc1ccc(C(=O)OCc2cccc(OC(C)(C)C)c2)cc1
# % of correct molecules is 100.00
# O=C(Nc1cc2ccncc2cc1)c1ccc(Cl)c(Cl)c1
# % of correct molecules is 100.00
# COC1CC(c2ccc(OCCCCNc3cc(-c4cccc(Cl)c4)no3)c(-n3nc(C)s3)c2)C(=O)OC1C
# % of correct molecules is 100.00
# COCCOC(CO)C(=O)NCCN(Cc1ccccc1C)C(=O)O
# % of correct molecules is 100.00
# CC(C)CCCN1CCN(S(=O)(=O)c2ccc(C(=O)Nc3nn[s+]([O-])c3)cc2)CC1
# % of correct molecules is 100.00
# CCC(C)C(CN=C(S)NC(=O)CNC(=O)OCc1ccccc1)C(O)CC(=O)NC(Cc1ccccc1)CC(C)C
# % of correct molecules is 100.00
# Cc1nc(-c2ccc(Nc3cc(-c4cc(OC)c(OC)c(OC5CCCP(=O)(O)C5)n4)o3)cn2C)ccc1C(=O)O
# % of correct molecules is 0.00
# O=S(=O)(Nc1cccnc1)c1csc2ccccc12
# % of correct molecules is 100.00
# COc1cccc(C2=C(NC(=O)c3cccc4cccnc34)Cc3ccccc3O2)c1
# % of correct molecules is 100.00
# O=c1[nH]c(=O)c2c(c3occc3c1=O)NCC2
# % of correct molecules is 100.00
# CS(=O)(=O)c1ccc(-n2c(-c3c(CC(=O)O)cccc3Cl)c3ccccc3c2C(=O)c2ccccn2)cc1
# % of correct molecules is 100.00
# CCC(=O)NN=Cc1ccc(OC)cc1
# % of correct molecules is 100.00
# CC(Oc1ccc([N+](=O)[O-])cc1Cl)=C1C(=N)NS(=O)(=O)c2ccccc21
# % of correct molecules is 100.00
# CCCCCCCNCc1ccc(S(=O)(=O)NCCO)cc1
# % of correct molecules is 100.00
# Cc1cc(C(=O)N2CCC(c3cccc(CN4CCN(C(C)C)CC4)CC3)s2)sn1
# % of correct molecules is 0.00
# O=S(=O)(c1ccc(Sc2ccccc2)cn1)N1CCN(c2cccc[n+]2C1)CCO2
# % of correct molecules is 0.00
# COc1ccc(S(=O)(=O)NC2=NC(CCC(=O)N3CCOCC3)C(c3ccc(O)cc3)C2=S)cc1
# % of correct molecules is 100.00
# Cc1nnc(-c2c3c(n(OC(=O)c4ccc5c(c3)OCCO5)c3C#N)CCN(C)CC2)s1
# % of correct molecules is 0.00
# CCOC(=O)c1cc(CC(C)CC(=O)OC)nn1Cc1ccccc1
# % of correct molecules is 100.00
# COc1ccc(C(=O)NC(C=Cc2ccc(Cl)cc2)S2(=O)=O)ccc2c1OC
# % of correct molecules is 100.00
# COC1C(=O)N2C(C1)C(c1cc(OC)c(OC)cc1OC)C2)C1CCN([Si](C)(C)c2ccccc2OC)CC1
# % of correct molecules is 0.00
# COC(=O)Nc1nc2cc(Cl)ccc2nc1SCC(=O)O
# % of correct molecules is 100.00
# CN=C(S)N1CCn2nc(CN3CCCCCC3)cc2C1
# % of correct molecules is 100.00
# CCCCCCCCCCCCCCCCOCC(COP(=O)1O[N+](=O)[O-])OC1C(OC(=O)NC(C)(C)C)C=C(C)OC1=O
# % of correct molecules is 0.00
# Cc1ccccc1S(=O)(=O)NCC1CC(=NNc2ccccc2)C(CCO)C1
# % of correct molecules is 100.00
# c1nc(O)c2ccccc2n1
# % of correct molecules is 100.00
# COc1cc2ncc(-c3ccc4c(c3)C(CCCCCCCCCCN=C(O)Nc4ccc(CN5CCN(C(=O)C6CC6)CC5)nn3)c(C)n3)on2)c1C
# % of correct molecules is 0.00
# C=CCC(=O)CN1CCc2c(-c3ccccc3)nc3ccccn3c2C1
# % of correct molecules is 0.00
# CSCc1c(C)noc1CCCNCCCN(Cc1ccccc1)C(=O)Cn1cnc2c(N)ncnc21
# % of correct molecules is 100.00
# CC(NC=CC=CCCCCCCC(=O)O)C(=O)O
# % of correct molecules is 100.00
# CCc1cccc2c1C(=O)C=C1CC(CC(=O)N(CC)CC)CCCC21
# % of correct molecules is 100.00
# Cc1cc(CSc2ncnc3c3ncnc(N)n2)ccc1C(=O)N1C(C)CCCC1(C)CO2
# % of correct molecules is 0.00
# Cc1cc(SCC(=O)Nc2ccc(-n3c(Cc4ccccc4Cl)nnc3-c3ccc(S(=O)(=O)Nc4ccccc4)cc3)o2)cn1
# % of correct molecules is 0.00
# COc1ccc(N2CC3C=CC2CN(c2ccc(Br)c(Cl)c2)CC3)cc1
# % of correct molecules is 100.00
# O=C(Nc1ccc(CCCc2ccccc2)cc1)CCSCC(=O)NCCc1cccs1
# % of correct molecules is 100.00
# Cn1c(N2CCCCC2)nc(=O)c2ccc(-c3cccc(OCC)n3)cc21
# % of correct molecules is 100.00
# CCC(C)C(NC(=O)C=CC=CCCCC)C(=O)O
# % of correct molecules is 100.00
# CCn1ncc2c(=O)c3ccccc3[nH]c2c1=O
# % of correct molecules is 100.00
# Cc1cc(C)cc(OC(=O)c2cc(C(C)(C)C)ccc2O)n1
# % of correct molecules is 100.00
# COc1ccc(Cl)cc1CNC(=N)NCCCC(N)=O
# % of correct molecules is 100.00
# CC(=O)OCC1OC(n2c(C)n(Cc3ccc(Cl)cc3)c2=O)C(=O)C(C)C1O
# % of correct molecules is 0.00
# Cc1ccc2c(Cc3cc4c(s3)OCO4)sc(CCO)c2c1
# % of correct molecules is 100.00
# CN(C)CCOc1ccc2cnn(-c3ccc(N(C)C)cc3)c2c1
# % of correct molecules is 100.00
# CSc1nc(-c2ccc(-c3ccc(Cl)cc3Cl)cc2)nn1Cc1ccccc1
# % of correct molecules is 100.00
# CCn1cc(-c2ccc(-c3c(-c4ccccc4)c(-c4c(C(C)=O)cs4)cn3)nc2)no1
# % of correct molecules is 0.00
# O=C(NCc1ccc(Cl)cc1)c1cc(O)cc(O)c1
# % of correct molecules is 100.00
# Clc1cccc(NC(=S)NC2=NCCS2)c1
# % of correct molecules is 100.00
# CC(=NC(=O)c1ccc(Cl)cc1)C1CCCN=C1
# % of correct molecules is 100.00
# CCNC(=S)NC(=O)c1c(C)n(Cc2cccc(Cl)c2)nc1Oc1ccccc1
# % of correct molecules is 100.00
# Cc1ccc(NC(=O)CSc2nc(Nc3ccc(C4CC4)nc3CC3COc4cc(C)noc4C3)cs2)cc1
# % of correct molecules is 0.00
# COc1ccc(C(=O)N(Cc2ccc(S(=O)(=O)N3CCOCC3)cc2)S(=O)(=O)c2ccccc2)cc1
# % of correct molecules is 100.00
# COC(=O)CCCSCC(=O)NC1CC(=O)N2C(C(=O)O)=C(COc3ccc4[nH](C)CCN4c3cccc4c(Cl)cnc43)CC2(C)C1=O
# % of correct molecules is 0.00
# Cc1ccccc1CNC(=O)c1ccc(N=O)cc1
# % of correct molecules is 100.00
# CN(C)Cc1cc(=O)c2ccccc2[nH]1
# % of correct molecules is 100.00
# Cc1cccc(Nc2nc(N3CCCCCC3)c3ccccc3n2)n1
# % of correct molecules is 100.00
# COc1ccccc1C1=NNC(=O)C2CN(C(=O)c3cccs3)CC2C3CC3CC31C(=O)c1ccc(C)cc1
# % of correct molecules is 0.00
# Cc1csc2c1c(NCc1ccc(Cl)cc1)n3CCCC2
# % of correct molecules is 0.00
# COc1ccc(-c2ccnc(NCC3CCCO3)c2NC(=O)NC2CC2)cc1
# % of correct molecules is 100.00
# Oc1cc(-c2ccccc2)nn1Cc1ccccc1
# % of correct molecules is 100.00
# O=c1cc(-c2ccccc2)oc2c1COCC2
# % of correct molecules is 100.00
# COc1ccc(-c2cc(C(=O)NN=Cc3c(-c4cccc(Cl)c4)no3)ccc2OC)c(C)c1
# % of correct molecules is 0.00
# O=C(Nc1ccccc1Cl)c1ccc2c(c1)OCCO2
# % of correct molecules is 100.00
# CC(CS(=O)(=O)c1ccc(Cl)cc1)NC(=O)CBr
# % of correct molecules is 100.00
# COc1ccc(-c2ccnc(Nc3cccc(Cl)c3)c2-c2ccc(S(N)(=O)=O)cc2)cc1[N+](=O)[O-]
# % of correct molecules is 100.00
# CC(C(=O)O)c1ccc(Cc2ccccn2)cc1
# % of correct molecules is 100.00
# OCCn1nc(C(=O)Nc2ccc(Cl)cc2)nn1
# % of correct molecules is 100.00
# CC(=O)N(CCOC)C(C)c1cccc(Br)c1
# % of correct molecules is 100.00
# O=[N+]([O-])c1ccccc1NCc1ccccc1
# % of correct molecules is 100.00
# O=C(NC1C2CCC1Cc1ccccc12)N1CCCC1
# % of correct molecules is 100.00
# Cc1ccc(Cn2cc(-c3ccc(C(=O)NCC(O)c4ccc(O)cc4)nn3)c2)cc1
# % of correct molecules is 0.00
# O=C(O)c1ccc2cc(Br)nc(NC(=O)c3cccc(Cl)c3)c2n1
# % of correct molecules is 100.00
# COc1cccc(CCCN2CC3CCC(C2)N2CCC3(C)CCN(O)C2=O)c1
# % of correct molecules is 100.00
# ON=C(Nc1cccc(C(=O)NCCCCCCN2CCOCC2)c1)c1ccc(CNc2c3ccccc3nc3ccccn23)cc1
# % of correct molecules is 0.00
# COc1nc(OC)nn(CC(=O)O)c1C
# % of correct molecules is 0.00
# OC(COCc1ccccc1)c1ccc(N2C(=O)C(NCCCN=Cc3c[nH]c4ccccc34)C2=O)cc1
# % of correct molecules is 100.00
# CCCCCCCCCCCCCC(=O)Nc1cccc2ccccc12
# % of correct molecules is 100.00
# CNc1ncnc2c1c(C)nn(C)c1=O
# % of correct molecules is 0.00
# COc1ccc(OCc2cc(N3CCN(Cc4csc([N+]4=CC#N)c4cc5cc(OC)c(OC)cc5n4)nnn3)cc2)cc1
# % of correct molecules is 0.00
# COc1ccc(C(=O)N2CCN(C(=O)COC(=O)CC(=O)NCC3(C)CC2)SCS(=O)(=O)Nc2ccc(Cl)c(S(C)(=O)=O)c2)cc1
# % of correct molecules is 0.00
# CC(NC(=O)Nc1ccc(C(=O)NCC(CC(C)C)S(=O)(=O)c2nnc(C3CC3)s2)cc1)C(=O)C=CC(=O)N1CCN(C)CC1
# % of correct molecules is 100.00
# O=Cc1ccc(-c2cccnc2-c2c[nH]nn2)c(OCc2cccc(O)c2)o1
# % of correct molecules is 0.00
# COc1ccc(C(=O)NNC(=O)c2ccc(Br)cc2)cc1
# % of correct molecules is 100.00
# COc1ccc(S(=O)(=O)Nc2c(C(=O)NC(C)C(=O)O)cc(OC)cc2NS(=O)(=O)c2c(C)c(C)ccc2N2CSCC2Cc2ccc(C3(C2)C(=O)O)cc2OCC(=O)O)cc1
# % of correct molecules is 0.00
# Cc1ccc2c(c1)OC(=O)C2=C1CCC(=O)N1CCCC(C)Nc1ccc(C)cc1
# % of correct molecules is 100.00
# COC(=O)NC(Cc1ccc(O)cc1)C(=O)NCC(=O)NB(CC(=O)O)N1C(=O)C=C(C)NC1c1ccccc1
# % of correct molecules is 100.00
# Cc1ccc(S(=O)(=O)OC(=O)C=Cc2ccccc2)cc1
# % of correct molecules is 100.00
# COc1cc(CCC(=O)NC2C(=O)OCC2O)ccc1OCCCC(=O)Nc1ccccc1O
# % of correct molecules is 100.00
# Cc1nn2c(NCc3ccccc3)SCCCBr)[nH]c2n1
# % of correct molecules is 0.00
# C=CC(C)(N)CCCC1CCC(N)CC1
# % of correct molecules is 100.00
# O=C(NCc1ccccc1)c1csc2ccccc12
# % of correct molecules is 100.00
# COc1cc(C=CC(O)=Nc2ncc(C)n(-c3ccccc3OS(=O)(=O)c3ccc(Cl)cc3)n2)ccc1C(=O)NCc1ccc(Cl)cc1
# % of correct molecules is 0.00
# CSc1ccccc1C(=O)NC(C)C(=O)NCc1ccc(-c2ccccc2-c2nn[nH]n2)cc1
# % of correct molecules is 100.00
# Cc1cc(O)c(C)c(C(=O)NCCN(=O)NC(C)C2(C(=O)NC(C(=O)O)C(=O)NC(COC(N)=O)Br)C(=O)N2)c1
# % of correct molecules is 0.00
# CN(C)CC#Cc1ccccc1-c1noc(NS(=O)(=O)c2cnc(C(C)(C)C)n2Cc2cccc(C#N)c2)c1
# % of correct molecules is 100.00
# Oc1ccc(COc2ccccc2Cl)c2c1C1C(c3ccccc3)=C(NC3Cc3ccccc3C2)CC1O
# % of correct molecules is 0.00
# CCCCCOP(=O)(OC)OC(=O)Nc1ccc2[nH]c(-c3ccc(Cl)cc3)nc2c1
# % of correct molecules is 100.00
# O=C1CCN(S(=O)(=O)c2cccc3ccccn23)C2CCN(S(=O)(=O)c3cccs3)CC21
# % of correct molecules is 0.00
# CCCN(CCC)CCCOc1ccc(-c2nc(C)cc(C)n2)cc1
# % of correct molecules is 100.00
# COc1cc(C=CC(=O)c2sc3cc(O)ccc3c2Cl)nc2c1c(CC)nn21
# % of correct molecules is 0.00
# COc1cccc(CN(C)S(=O)(=O)c2c(N)nc3cc(Cl)ccc3n2)c1
# % of correct molecules is 100.00
# COc1cccc(C=CC(=O)c2ccc3c(c2)OCO3)c1
# % of correct molecules is 100.00
# CCOC(=O)C(C)(C)SC(C)=O
# % of correct molecules is 100.00
# COc1ccc(OCCNCC(O)COc2ccc(-n3ncc(=O)oc4c(=O)c3=O)c(OC)c2)cc1
# % of correct molecules is 0.00
# Cn1ccnc1CNC(=NC1CCCCC1C(=O)NCC(=O)NCc1ccc(Cl)cc1)C(=O)Nc1ccccc1
# % of correct molecules is 100.00
# CCC(N)C(=O)NC(C(=O)NC(CCC(C)C)NC(=O)c1ccccc1O)OCc1ccccc1
# % of correct molecules is 100.00
# CCCCCCCCCn1cc(CC(N)=O)nc1=O
# % of correct molecules is 0.00
# Cn1c2c(N3CCN(c4ccc(CC(N)Cc6ccc6nc(=O)[nH]c(=O)[nH]c5c5cnccc76)cc4cc3Cl)CCC3)cccc2n1
# % of correct molecules is 0.00
# CC(NP(=O)(c1ccccc1)c1ccccc1)OCc1cn(nc2ccccc12)c1ccccc1
# % of correct molecules is 0.00
# O=Cc1c(-c2ccc(Br)cc2)ncnn1-c1ccc(C(=O)O)c2ccccc12
# % of correct molecules is 0.00
# CN(c1ccccc1)c1ncc2c(n1)CN(c1ccc3c(c1)-c1cc(-c4ccoc4)nc(N4CCOCC4)n1)CC2
# % of correct molecules is 0.00
# O=C(Oc1cc2c(cc1n3CCN1CCC1)C(=O)c1cccc3c1C(=O)c1ccccc1O2)c1ccccn1
# % of correct molecules is 100.00
# Nc1nccc2c1nc2c3ccccc3nc12
# % of correct molecules is 0.00
# CN(C)S(=O)(=O)N1CC2CSC2(C(=O)NCCc2nccnc2Nc2cccc(Cl)c2)C1
# % of correct molecules is 100.00
# Cc1cn(C2=CC(=O)c3ccccc3C2=O)c(=O)n1Cc1ccc(O)cc1
# % of correct molecules is 100.00
# Cc1cc(C2=NC(c3cccc(Cl)c3)C(=O)N2c2ccccc2)c(C)c(Br)c1O
# % of correct molecules is 100.00
# Cc1cc(NC(=O)c2cccs2)nc(N2CCN(c3ccccc3)CC2)n1
# % of correct molecules is 100.00
# CCOC(=O)c1ccnc(-n2nc3ccccc3c2=O)c1
# % of correct molecules is 0.00
# CCN1(C)CCN(c2cc(C)n(CC(=O)NC3(c4ccc(-c5ccccc(=O)c5)nn4)=NC3=O)cc2)CC1c1ccccc1
# % of correct molecules is 0.00
# CCCCOc1ccccc1CN=C(S)Nc1ccccc1N=Cc1ccc(OC)cc1
# % of correct molecules is 100.00
# Cc1ccc(OCCCCCn2c(C)nnc2Nc2nc(C)cc(N(C)C)n2)cc1C
# % of correct molecules is 100.00
# CN(C)C(=O)c1nc2c(s1)CCC(NS(=O)(=O)c1ccc(-c3ccco3)cc1)C2
# % of correct molecules is 100.00
# COc1ccc(C(=O)N2CC3CCCN2C(=O)C(c2ccccc2)n2(C)C)cc1
# % of correct molecules is 0.00
# Cc1ccc(C(=O)OC(C)C(=O)Nc2ccccc2C(=O)O)cc1
# % of correct molecules is 100.00
# CCCCCCCCCCCCNC(=O)C(CC)NC(=O)Oc1ccccc1
# % of correct molecules is 100.00
# CCC(=O)N1CCN(C(S)=C(C#N)c2nc3cccc(s3)c(=O)c2C(N)=O)CC1
# % of correct molecules is 100.00
# CCOC(=O)c1c(NC(=O)c2cc3ccc4c(c23)CCCC3)cc(=O)oc1C
# % of correct molecules is 0.00
# COc1cccc(CN2C(=O)Cc3c([nH]c4ccccc34)C2c2cccc(C)c2)c1
# % of correct molecules is 100.00
# O=C(CCN(CCCl)Cc1cccc(O)c1O)NCCc1ccccc1
# % of correct molecules is 100.00
# Cc1cc2c(cc1C)C(CC(=O)NCCc1ccccc1Cl)=NCc1ccccc1C2=O
# % of correct molecules is 100.00
# N#Cc1ccc(Sc2ccccc2-c2nn[s+](-c3ccc(Cl)cc3)n2C2OC(CO)C(O)C2O)cc1
# % of correct molecules is 0.00
# c1ccc(CN2CCN(CCc3ccccc3)CC2)n1
# % of correct molecules is 0.00
# CN1C(=O)CC(Sc2nccc(Nc3nccc(-c4cc5cncnn6nccnc55)c3)c2)CC1
# % of correct molecules is 0.00
# CC(C)NCC(O)c1ccc(NC(=O)c2cc([N+](=O)[O-])ccc2O)cn1
# % of correct molecules is 100.00
# CC(NC(=O)OC(C)C)C(=O)NS(=O)(=O)c1ccc(Cl)cc1
# % of correct molecules is 100.00
# O=C1CSC(=NNc2cccc(Cl)c2Cl)N1
# % of correct molecules is 100.00
# COc1ccc(NC(=O)NC(C)c2noc(C)c2C(=O)c2ccccc2)cc1
# % of correct molecules is 100.00
# O=C1CC(c2csc3c(=O)cc(N4CCCc4ccccc44)cc2-c2ccncc2)OC1
# % of correct molecules is 0.00
# CCSc1nnc(N=C(N)N)s1
# % of correct molecules is 100.00
# Cc1cc(NC(=O)CSc2nc(Br)c3cccnc3c2-c2ccccc2)sc1C
# % of correct molecules is 100.00
# COc1cc(C=NNC(=O)CN2C(=O)c3ccc(Cl)c(Cl)c3C(=O)N2Cc2ccccc2)cc(OC)c1OC
# % of correct molecules is 100.00
# CC(C)(O)CC(=O)C=CC=CC=CCCCCCCC(=O)O
# % of correct molecules is 100.00
# CCOC(=O)c1cc2cc(OCCC(=O)OC)ccc2c2cc(-c3c(C(=O)NCCCCCN4CCOCC4)nnc3sccc23)CC1
# % of correct molecules is 0.00
# Cc1c(C(=O)NO)cnc2ccc(S(=O)(=O)Nc3ncccn3)c(C)c12
# % of correct molecules is 100.00
# CC(C)CC(NC(=O)C(N)Cc1ccc(O)cc1)C(=O)NCCc1ccccc1
# % of correct molecules is 100.00
# Cc1ccc(C=NNC(=S)N2CCOCC2)nn1
# % of correct molecules is 100.00
# CC(C=CC=CC=CC=CC(=O)O)=CCC(C(C)C=CC=CC)(CC)C(=O)O
# % of correct molecules is 100.00
# Cn1c(=O)c2c(nc3n2CCN(C(c2ccccc2)c2ccccc2)C3)n(C)c1=O
# % of correct molecules is 100.00
# CCc1cccc(CN(C)CCCNC(=O)C2CCCN(S(=O)(=O)c3cccs3)C2)c1
# % of correct molecules is 100.00
# O=C1NC(=O)C(c2cccc(Br)c2)=C1C=Cc1ccccc1
# % of correct molecules is 100.00
# CCCN(CCC)CC(O)CCOc1ccc(N(CC)CC)cc1
# % of correct molecules is 100.00
# CCN1CCN(C)CC1
# % of correct molecules is 100.00
# O=C(O)CNC(=O)C(Cc1ccccc1)NC(=O)CN1C(=O)CC(C(=O)N2CCCCCC2)C(Cl)=C(Cl)C1c1ccccc1
# % of correct molecules is 100.00
# CNCC(C)N1CCN(c2ccc(Cc3ccc(Cl)cc3)cc2C=O)CC1
# % of correct molecules is 100.00
# Cc1nc(NN=Cc2ccsc2)c2nc(N3CCNC3)nc(N)c3n1)c1cccc2[nH]1
# % of correct molecules is 0.00
# CN(CCCl)CCP(C)(=O)Nc1ccccc1OCc1nc2ccccc2s1
# % of correct molecules is 100.00
# Cc1cccc(Br2Cc3c(sc4ncnc(NC(N)=O)NC(C(C)(C)C)CC4)n3c21
# % of correct molecules is 0.00
# COc1ccc(CCN(Cc2ccccc2Cl)S(=O)(=O)c2cccc(C(=O)O)c2)cc1
# % of correct molecules is 100.00
# Cc1c(C(=O)Nc2sccc2-c2ccc3ccccc3c2)c2ccc(OC)cc2s1
# % of correct molecules is 100.00
# Cc1cc(C(=O)NNC(=O)c2ccc(S(N)(=O)=O)cn2)on1
# % of correct molecules is 100.00
# CC(=O)Nc1ccccc1CN(C)C(=O)C(Cc1ccccc1)NC(C)C(=O)NC(C(=O)N1CCc2ccccc2S1(=O)=O)C(c1ccccc1)c1ccccc1
# % of correct molecules is 100.00
# NC(Cc2ccccc1)C(=O)NC1(C(=O)NC(CCC(=O)O)C(=O)O)CC(c2c(O)cccc2S(=O)(=O)Cc2ccccc2)OC1=S
# % of correct molecules is 0.00
# NC(Cc1ccccc1)C(=O)NC(CCCNC(=N)N)C(=O)O
# % of correct molecules is 100.00
# Cc1ccc2c(c1)C1(CCN3C(=NC(=O)CSc4c(Cl)cnc4cccn34)=NC3COC(=O)N3C)CCC(C)C12
# % of correct molecules is 0.00
# CC(=O)NC(c1ccccc1)c1ccccc1
# % of correct molecules is 100.00
# CCC(C(=O)Nc1cccnc1OCC1OC(n2cnc3c(=O)n(C)c(=O)nc32)CC1=O)Oc1ccccc1
# % of correct molecules is 0.00
# Cc1cc(C)ccc1C(=O)NCCC(=O)NN
# % of correct molecules is 100.00
# CC(C)NCC(O)COc1ccc(Cl)cc1
# % of correct molecules is 100.00
# N#CC=Cc1ccc(-c2cccc([N+](=O)[O-])c2)cc1
# % of correct molecules is 100.00
# Cc1ccc(NC(=O)CCC(=O)c2ccc(CSc3nnc(-c4ccccc4Cl)n3)s2)cc1
# % of correct molecules is 0.00
# CCc1cc2c(cc1C)OC(c1cccc(O)c1)O2
# % of correct molecules is 100.00
# COc1cc(C)c(C(=O)OCC(=O)NC2CCCC2)cc1
# % of correct molecules is 100.00
# CCOCC(O)COc1ccc(C2CCN(C(C)=O)CC2)cc1C
# % of correct molecules is 100.00
# CCN(CC)c1ccc(-c2ccnc(Nc3cccc(Cl)n3)n2)cc1
# % of correct molecules is 100.00
# CC=CC(=O)c1c(N)ccc2ccc(OCc3ccc(OC)cc3)nc21
# % of correct molecules is 100.00
# CCC(=O)N1CCCC1c1ccc(Cl)cc1
# % of correct molecules is 100.00
# CCn1cc(NC(=O)CC(=O)N(C)C)c2ccc(Cl)cc2c1=O
# % of correct molecules is 100.00
# CCCCN1CCN(c2cccnc2)CC1
# % of correct molecules is 100.00
# Cc1ccc2[nH]c(CCC(=O)NN)cc2c1
# % of correct molecules is 100.00
# CCCCCCCCCCCCC=CC=CC(=O)O
# % of correct molecules is 100.00
# N#CC1=C(N)NS(C)(=O)=C1c1ccc(S(=O)(=O)N2CCC(O)(CNC(=O)CC2c3ccccc3C(C)(C)C)CC2)cc1
# % of correct molecules is 0.00
# CC(C)n1c(N)[nH]c(C=O)c1-c1ccc(NC(=O)c2ccc(CCCCCCN)[nH]3)c2)cc1
# % of correct molecules is 0.00
# COc1ccccc1CN1C(=O)c2ccccc2C1=NOc1cccc(S(=O)(=O)N(C)CC=C)c1
# % of correct molecules is 100.00
# c1ccc(COCC2CCCC2)s1
# % of correct molecules is 100.00
# CN1CCCC1c1cc(-c2cc3ccccc3o2)ncn1
# % of correct molecules is 100.00
# CCc1ccc(COc2nnc3ccc(N4CCOCC4)nc3c2)cc1
# % of correct molecules is 100.00
# CC1Cc2c(NCC3CCCNCC3)nc(NC3CCCCC3)nc2-c2cc(I)ccc21
# % of correct molecules is 100.00
# Cc1ccc(S(=O)(=O)Nc2ccccn2)cc1S(=O)(=O)c1ccsc1
# % of correct molecules is 100.00
# CC(=NNc1ccccc1)c1ccccc1
# % of correct molecules is 100.00
# CCOC(=O)c1c(NC(=O)c2ccc(-c3ccccc3)c(S(N)(=O)=O)c2)ccc2sc(C)nc21
# % of correct molecules is 100.00
# Oc1ccc(Br)cc1C=NN=Cc1ccc2ccccc2c1O
# % of correct molecules is 100.00
# CCC(C)C(NC(=O)C1C2(C)CCC3(C)C(CCC4C5(C)CCC(OC(=O)C(C#C)C(C)(C)C)C4C(=O)OC(C)(C)C)C3(C)C(C=O)=C(N)N1C)C2=O)C(O)=CP(=O)(O)O
# % of correct molecules is 0.00
# CCN1CCN(C(=O)c2cc3c(cc2CC)nc2n3cccc3c2=O)CC1
# % of correct molecules is 0.00
# Cc1cccc(C(=O)NC(C(C)C)C(=O)NCc2ccccn2)c1
# % of correct molecules is 100.00
# Cc1ccc(COc2cc(CCN(CC)CC3CCC(O)C3)ncc2Cl)c2cccnc12
# % of correct molecules is 100.00
# Cc1nc(N(C)c2nc(-c3cnn(-c4ccc(Cl)cc4)n3)c3ccccc3n2)nc(N2CCCC2)c1C(O)=NN=Cc1ccc(C)cc1
# % of correct molecules is 100.00
# O=C(Cn1ncc2cc(Cl)cnc21)N1CCOCC1
# % of correct molecules is 100.00
# Cc1nc(-c2cc(=O)oc3c(Br)cccc23)cn1CC
# % of correct molecules is 100.00
# CCCCOc1ccccc1
# % of correct molecules is 100.00
# Cc1ccc(Nc2cc(-c3ccncc3)nn2-c2nccs2)cc1
# % of correct molecules is 100.00
# CC(=CC(=O)NC1C2CCC3CC(C1)C(=O)C1(C)C(C3=[N+]=[N-])C1(O)C(C)(C)O2)C(=O)C(C)=O
# % of correct molecules is 100.00
# O=C(Cc1ccccc1)N1CCN(C(=O)NCc2ccc3c(c2)OCCO3)CC1
# % of correct molecules is 100.00
# O=C(c1cccc2ccccc12)N1CCc2ccccc21
# % of correct molecules is 100.00
# CC(=O)c1cccc2c1C(=O)OCc1c(Cl)c(CC(=O)O)nc(CCNC(=N)N)c1-3
# % of correct molecules is 0.00
# c1csc(-c2ccc(-c3nnc4sc(CN5CCN(c5ccccc6NC5=O)cnc43)CC2)cc1
# % of correct molecules is 0.00
# Cc1ccc(SCCCCN2C(=O)CC(c3cccs3)C2c2ccc(Cl)c(Cl)c2)c(Br)c1
# % of correct molecules is 100.00
# COc1ccc(CN(C(=O)CCN(C)C)c2ccc(OC)cc2)cc1
# % of correct molecules is 100.00
# CCCCCCN(CC(=O)Nc1ccc(S(N)(=O)=O)cc1)C(=O)NC1CCS(=O)(=O)C1
# % of correct molecules is 100.00
# Nc1ncc2c(n1)CCCC2
# % of correct molecules is 100.00
# CCC(=O)OC1CN(c2ccccc2)CC1C(=O)O
# % of correct molecules is 100.00
# NCCCNCCCCNCCCNCCOCCCCCC
# % of correct molecules is 100.00
# Cc1nc2ccc(-c3ccc(NS(C)(=O)=O)cc3Cn3nc(-c4ccncn4)nc3[nH]2)n1
# % of correct molecules is 0.00
# Cc1cc2cccc(-n3ccnc(NCCc4ccc(C(C)=O)cc4)c3O)c2cc1C(N)=O
# % of correct molecules is 0.00
# N#CC(=Cc1ccc(=O)n(C)n1)c1ccccc1
# % of correct molecules is 100.00
# Cc1ccc(NC(=O)CSc2nc3c4ccccc4cc3s2)cc1-c1ccc(Cl)cc1
# % of correct molecules is 0.00
# COc1ccc(-n2c(=O)c3sc4ccc(C(=O)NCCc4ccccc4)cc3c2N)cc1
# % of correct molecules is 0.00
# CC(C(=O)N1CCCC1C(O)CNC(Cc1ccccc1)(C(O)CS)C(C)C)C(=O)O
# % of correct molecules is 100.00
# O=S(=O)(Nc1ccc(Br)c(Cc2cccc(Cl)c2)c1)C1c2ccccc2SC1(c1ccccc1)c1ccccc1
# % of correct molecules is 100.00
# CN(C)C(=O)CSc1nnc(-c2cccnc2)o1
# % of correct molecules is 100.00
# Cc1cccc(CNC(=O)c2ccc(OCC3CCN(Cc4ccncc4)CC3)cc2)c1
# % of correct molecules is 100.00
# CCn1cc(C2CCN(C(=O)c3ccc(Cl)c(Cl)c3)CC2)cn1
# % of correct molecules is 100.00
# Cc1onc(CN(C)c2nn(Cc3cccc(Cl)c3Cl)cc2NC(=O)c2cc3c(o2)CCN(CC3c4ccccc4SC2)C3)c1C
# % of correct molecules is 0.00
# CC(C)n1nc2c(c1=O)C(O)CC2=O
# % of correct molecules is 0.00
# COc1cc(CN(CC(=O)NCCC(=O)O)C(=O)Nc2ccccn2)cc(Br)c1OC
# % of correct molecules is 100.00
# O=c1cc2cc(-n3coc3ccnc3P(=O)(COP(=O)(O)O)CC2)nc2ccccc12
# % of correct molecules is 0.00
# CC1OC(n2ccc(=O)[nH]c2=O)CC2OC(c3ccccc3)OC12
# % of correct molecules is 100.00
# CCOC(=O)Cc1cc2cc(CSc3ccc(OC)cc3)cc(=O)n2c2ccccc12
# % of correct molecules is 100.00
# CC(C)C(N)N=C(C)c1ccccc1
# % of correct molecules is 100.00
# NC(=O)CN(Cc1ccccc1Cl)C(=O)c1sc2nc(=O)n(Cc3ccccc3)c2n1
# % of correct molecules is 0.00
# Cc1ccc(S(=O)(=O)N(CC(=O)NCc2cccs2)S(=O)(=O)c2ccc(Cl)c3c2OCCO3)c(N)s1
# % of correct molecules is 0.00
# COc1cccc(NC(=O)c2ncco2)c1
# % of correct molecules is 100.00
# Cc1ccccc1CN=C(O)C(CCc1nc2ccccc2[nH]1)=n1c2ccccc2n2C(=O)c3ccccc3C1=O
# % of correct molecules is 0.00
# O=C(O)C(Cc1ccc(Cl)cc1)NOC(=O)C(OC1CCCCC1)C(O)C(O)CO
# % of correct molecules is 100.00
# CC(CC(=O)N(Cc1ccccc1Cl)c1ccccc1)C(=O)Nc1ccccc1C(=O)O
# % of correct molecules is 100.00
# COc1ccc2cc(C(=O)O)c(O)cc2c1
# % of correct molecules is 100.00
# c1ccc(CNc2ncnc(N3CCOCC3)n2)cc1
# % of correct molecules is 100.00
# Cc1cc(NC(=O)C[n+]2ccccc2)ccc1Oc1cccc2ccccc12
# % of correct molecules is 100.00
# CCCCCNC(=O)c1c(O)ccc2c(-c3ccccc3)nc(SCC(=O)NC3CC3)nc12
# % of correct molecules is 100.00
# Cc1ccc(CNC(=O)c2[nH]nc(-c3ccc(S(C)(=O)=O)cc3)n2)cc1
# % of correct molecules is 100.00
# COc1ccc(NC(=O)c2nnc3c4ccccc4n(CC(=O)Nc3ccc(Cl)cc3)n2Cc2ccc(NC(=N)N3CCCC3)cc2)cc1
# % of correct molecules is 0.00
# CC(C)(C)NC(=O)N(Cc1ccccc1)C(=O)C1CCN(c2ncccn2)CC1
# % of correct molecules is 100.00
# COc1cccc(-n2nc(-c3cccc(S(=O)(=O)NC(=O)Nc4cc(C(=O)Nc5ccc(-c6ccnn6C)cn5)n4-c4cc(Cl)ccn4C)c(OC)c3)c(Cl)c2)c1
# % of correct molecules is 0.00
# CCC(CC)(c1cccc(OCC(=O)NCC=C)c1)c1ccccc1
# % of correct molecules is 100.00
# CCCC(=O)Nc1ccc(N2CCN(CNC(=O)c3ccco3)CC2)cc1
# % of correct molecules is 100.00
# Cc1nc(CSc2ccc(C(=O)Nc3ccnc(Nc4ccc(Cl)cc4Cl)c3)nc2)c2ccccc2[n+]1Cc1ccc(-c2ccccc2C)cc1
# % of correct molecules is 100.00
# Cc1cc(Cl)ccc1S(=O)(=O)N1CCC(OC(=O)N(C)C)c2ncsc21
# % of correct molecules is 100.00
# CN(CC(=O)NCc1ccc(-c2ccccc2)cc1)c1ccc(-c2ccccc2OCC(C)(C)C)cc1
# % of correct molecules is 100.00
# CCOc1ccc(CCN2C(=O)c3ccccc3N=C2c2ccc(C)c(CC)c2)cc1
# % of correct molecules is 100.00
# CCOC(=O)NC(C)C(CNC(=O)C(CC=C(C)CCCCCCc1c(C)on2C)n1C)C(C)C
# % of correct molecules is 0.00
# CN(C)CCCCCOc1ccc(-c2nc3ccc(C(=O)N4CCC(O)CC4)cc3[nH]2)cc1
# % of correct molecules is 100.00
# COc1cc2c(CNCCCCN3CCN(S(C)(=O)=O)CC3)nc(-c3ccc(C)cc3Cl)c1-c1cc(NC(=O)Nc3ccc(Cl)cc3)ccc1O2
# % of correct molecules is 0.00
# O=C(C=Cc1cnc(NCc2ccccc2)n(-c2ccccc2)n1)NCC1CC1
# % of correct molecules is 0.00
# CC1=CC2C(c3ccc(Cl)cc3)CC3Cc4c5cc(O)ccc5c4-n3n2C1OC(C1CC(=O)OC1)C3
# % of correct molecules is 0.00
# CC(C)(C)NC(=O)C(CCCNC(=N)N)NCc1ccc(SC)cc1
# % of correct molecules is 100.00
# Cn1cc(N2CCN(S(=O)(=O)c3ccc(CN)c(Cl)c3)CC2)c2ccccc21
# % of correct molecules is 100.00
# O=C(CCC1CCCC1)NC1CC1
# % of correct molecules is 100.00
# O=C(CC1CCN(c2ncnc3cc(CN4CCOCC4)nc(c23)CC1)OCCOc1ccc(-c2ccccc2)cc1)C1CC1
# % of correct molecules is 100.00
# COc1cc2c(cc2oc1=O)C(c1ccc(SC)cc1)n2cc(C)nc1OC2CCCCCCCCCCCCCCCCCCC
# % of correct molecules is 0.00
# Cc1nc2ccc(OCCCN3CCC(C(=O)NC(CCCC(=O)N)CC([N+](=O)[O-])CC4)cc3[nH]2)c1=O
# % of correct molecules is 0.00
# Cc1cc([N+](=O)[O-])cn1CN(Sn1cccn1)c1nccn1C)C(=O)c1ccccc1
# % of correct molecules is 0.00
# CC(C)Nc1cc(-c2ccccc2)oc2cc(S(=O)(=O)NC(CCCNC(=N)N)C(=O)O)c(O)cc12
# % of correct molecules is 0.00
# CCOC(=O)c1sc(CNc2ccc([Si](C)(C)C)cc2)nc1O
# % of correct molecules is 100.00
# c1ccn2c(-c3nc(-c4cc(NC(=O)NC5CCC5)ncn4)cn3CCc3ccccn3)oc2c1
# % of correct molecules is 0.00
# CC(=O)N1CCC2=C(CS(=O)(=O)C=Cc3ccccc32)C1
# % of correct molecules is 100.00
# COc1ccccc1-c1cc(NCc2ccccc2)cc(-c2ccc(Cl)cc2)n1
# % of correct molecules is 100.00
# Cc1ccc(C(=O)N2Cc3cc(Br)ccc3-n3nnc(CN4CCOCC4)n3)c2n1
# % of correct molecules is 100.00
# CC(C)(C)B1OC2C(SCC(=O)O)C(OCc3ccccc3Cl)=C(SC1=Cc2cccnc2)C2(C)C
# % of correct molecules is 100.00
# COc1ccc(C(=NO)C3CCCN(C(=O)Nc3ccccc3)C(c2ccccc2)N3Cc2ccncc2)cc1
# % of correct molecules is 100.00
# COc1cc(Cc2cc(C(=O)NC3CC[S+]([O-])C3)ccc2C)ccc1NC(=O)c1ccc(Cl)cc1
# % of correct molecules is 100.00
# CC(C)(C)C1CCCN(C(C)(C)Cc2ccccc2)CC1
# % of correct molecules is 100.00
# COc1cc(NC(=O)Nc2cc(=S)n3nc(-c4ccc(C)cc4Cl)nc3n2)ccc1OC
# % of correct molecules is 0.00
# CC(O)(c1ccccc1)n1c(-c2cccnc2)nc2ccccc21
# % of correct molecules is 100.00
# NC(=O)C1C(=O)N2CCC1(CC1)C(c1ccccc1)C1=Cc3cccc3ccc(=O)c12
# % of correct molecules is 0.00
# Cc1ccc(CCNC(=O)COc2ccc(CCC(=O)Nc3nccc(-c5cccc(NS(C)(=O)=O)c4)c3)on2)cc1
# % of correct molecules is 0.00
# Cc1ccc(C)c(NC(=O)Oc2cc3c(cc2n1)OCO3
# % of correct molecules is 0.00
# CC(=O)NC(C)c1ccccc1
# % of correct molecules is 100.00
# Cc1ccc(-n2nc(-c3ccc(-c4ccccc4)cc3)nc2C)cc1C=NCCc1ccccn1
# % of correct molecules is 100.00
# Cc1cc(C(=O)NCCS(=O)(=O)NC2CCCCCC2)nc2ccccc12
# % of correct molecules is 100.00
# C=C(C)CCC(C)C(=O)N(C)Cc1c(C)oc2ccccc2c1=O
# % of correct molecules is 100.00
# CCCC(CC)(c1cc(=O)n2c(=O)[nH]c(-c3ccccc3)[nH]c2c1Cl)NC(N)=O
# % of correct molecules is 0.00
# Cc1ccc(S(=O)(=O)c2nc(C3CCC(c4ccccc4)NC(=O)C3CC(=O)O)ccc2Cl)cc1
# % of correct molecules is 100.00
# O=C(C1CCN(Cc2ccccc2)(c2ccccc2)CC1)N1CCc2ccccc21
# % of correct molecules is 0.00
# O=c1c2cccnc2oc2cc(-c3cc(-c4ccc5c(c4)CCOc5ccccc5)[nH]c34)ccc12
# % of correct molecules is 0.00
# Cc1cccc(NC=C2C(=O)Nc3ccc(-c4ccc(C)cc4)nc32)n1
# % of correct molecules is 100.00
# COc1cc(CNc2c3cc(OC)c(OC)cc3nc2-c2ccsc2)cc(OC)c1
# % of correct molecules is 0.00
# Brc1cccc(Oc2cc(Br)c[nH]c2-c2ccc3c(c2)OCCO3)n1
# % of correct molecules is 0.00
# COc1c(C(=O)C=Cc2cccs2)n(CCC)nc1C
# % of correct molecules is 100.00
# O=C(C(c1ccccc1)c1cccc[n+]1[O-])c1ccccc1[N+](=O)[O-]
# % of correct molecules is 100.00
# COc1cc(Nc2cccc(-n3cccn3)c2)cc(OC)c1OC
# % of correct molecules is 100.00
# NCC(=O)N1CCc2cc(-c3ccccn3)oc2C1
# % of correct molecules is 100.00
# CCCCCCCCOC1CC(N)=NN(C)C(O)C(C2CCCCC2)C1
# % of correct molecules is 100.00
# O=C(CN1CCN(S(=O)(=O)c2cccnc2)OC1=O)c1ccc(-c2ccccc2-c2ccccc2)cn1
# % of correct molecules is 100.00
# CCC(NC(C)=O)C(=O)OCC1(C)CCC(C(C)(C)C)CC1O
# % of correct molecules is 100.00
# Cc1sc2nc(CN(C)CC(=O)NC3Cc4ccccc4C3)ccc2c1
# % of correct molecules is 100.00
# CCOC(=O)c1c(N)sc2c1OC12C(S)=C(C(=O)C(C-1)c1ccccc1-2)NN=Cc1cccc2ccccc12
# % of correct molecules is 0.00
# COCCNC(=O)CN1C(=O)c2cccc3c2O1)S(=O)(=O)c1c(cc(OC)c(OC)c1Cl)NC2=O
# % of correct molecules is 0.00
# COc1ccc(S(=O)(=O)CCC(=O)NNC(=O)c2ccc3cccnc3c2)cc1
# % of correct molecules is 100.00
# COC(=O)c1c(CC(C)C2CCCCC2)c(C#N)cn1
# % of correct molecules is 0.00
# Oc1ccc2sccc2c1-c1ccc(C2CCN(Cc3ccccn3)CC2)nc1
# % of correct molecules is 100.00
# O=c1c(Oc2c(CCCCc3ccccc3)n[nH]c2C2CCCCC2)ccc2ccnn12
# % of correct molecules is 0.00
# O=c1c2cccc(-c3ccccc3)c2nc2ccccc12
# % of correct molecules is 0.00
# CCOC(=O)CSc1nc(-c2cccc(OC)c2)nc2ccncc12
# % of correct molecules is 100.00
# COC(=O)c1cc2c(nc1N1CCN(C(=O)Nc3ncc(C#N)cn3)CCC1)CCC2
# % of correct molecules is 100.00
# OCCCCCC=CC(=O)N1CCc2cc(S(=O)(=O)Nc3[nH]nc4ccc(Br=CN(CC(=O)Nc5ccccc6Cc5cccs5)n5)cc4ccn32)n1
# % of correct molecules is 0.00
# Nc1ncnc2c1nc(-c1ccc(OCCN3CCOCC3)cc1)n2CCCN(C)c1nccs1
# % of correct molecules is 100.00
# COCCNC(=O)C1CC(CCCCCSSCC(=O)CCC(=O)NC(CCl)NC(=O)C(NC(=O)C(N)CC(C)C)C(C)CN(C)Cc2ccc(-c3ccncc3)cc2)CC1
# % of correct molecules is 100.00
# C=CCN1C(=O)Nc2ccc(C#N)cc2C1=O
# % of correct molecules is 100.00
# CCCCCCCCCCP(=O)(O)CCC(=O)Nc1c(C(C)C)cc(OCc2ccccc2)n(-c2ccc(C(=O)N(C)CC)c(CCCC)c2)c1=O
# % of correct molecules is 100.00
# COCCNC(=Nc1cc2cc(OC)cc(OS(=O)(=O)N(C)C)c2nc1O)CC(=O)O
# % of correct molecules is 100.00
# Cc1ccc(-c2nc3c(c(Br)[nH]2)OC3(O)c2ccc(S(=O)(=O)N4CCN(C)CC4)cc2-3)cc1
# % of correct molecules is 0.00
# CCOc1ccc(CNC(=O)C=Cc2ccc(Br)cc2)cc1
# % of correct molecules is 100.00
# O=C(O)CC(NC(=O)c1nc(-c2cccs2)os1)c1cccc(CN2CCCC2=O)c1Cl
# % of correct molecules is 0.00
# COc1ccc(-c2ccc3cnc(C)nc3c2)cc1
# % of correct molecules is 100.00
# O=C(Nc1ccc(CC=CP(=O)(O)O)cc1)c1ccc[nH]1
# % of correct molecules is 100.00
# NC(Cc1c[nH]c2cccc(Cl)c12)C(=O)N1CC(CCN2CCCC(C(=O)Nc3ccccn3)C2)CC1
# % of correct molecules is 100.00
# Cc1noc(C)c1-c1cc(-c2ccc(CC(N)CC(C)C)cc2)cc(Br)n1
# % of correct molecules is 100.00
# COc1ccc(-c2cccc3nc(-c4ccc(CN(C)C)cc4)cc(=O)c23)cc1
# % of correct molecules is 0.00
# Cc1c(SCCSc2ncc(C3CCC3)s2)nnc1-c1ccncc1
# % of correct molecules is 0.00
# CN1CCN(C2=Nc3ccsc3CC(=O)NC2=O)CC1
# % of correct molecules is 100.00
# CN(C)c1ccc2nc(N3CCN(C(=O)c4ccccc4)CC3)c(=O)c3c(s2)CCN3C(=O)C=CCC1(C)O
# % of correct molecules is 100.00
# CC(C)CC(NC(=O)c1ccccc1CN1CCC(Nc2cccc(C#N)c2)CC1)c1cccn1
# % of correct molecules is 0.00
# CC12C=C(C(=O)Nc3c5ccccc5c4[nH]c5c(cccc45)cc3C4(C(=O)O)CC12C)=CCC=C3O
# % of correct molecules is 0.00
# Nc1[nH]cnc2nc3ccccc3n12
# % of correct molecules is 0.00
# Nc1ccccc1C(=O)NN=Cc1ccc(-c2ccccc2)cc1
# % of correct molecules is 100.00
# CON=C1C(=O)OC(C)CC1=O
# % of correct molecules is 100.00
# CN(Cc1ccccc1)C(=O)CN1CCC(NC(=O)c2ccccc2OC)CC1
# % of correct molecules is 100.00
# Cc1cccc(NC(=O)Cc2snc(CCc3ccccc3Cl)n2)c1
# % of correct molecules is 100.00
# CCC[N+]1(CC2CCCO2)CCCC1
# % of correct molecules is 100.00
# CC(=O)C(=O)c1c(-c2ccc(OCC(=O)O)c(C=O)c2)oc2cccc3c12
# % of correct molecules is 0.00
# CCCCN1CCN(C(=O)c2ccc(Sc3nccc4ccc(-c5ccccc5Cl)cc34)c(Cl)c2)CC1
# % of correct molecules is 100.00
# CCN1CCN(CCNN(C)C(=O)c2ccc3ccccc3c2)CC1
# % of correct molecules is 100.00
# C=CC(=O)c1cc(-c2ccc(S(=O)(=O)N3CCCC3)cc2)sn1
# % of correct molecules is 100.00
# O=S(=O)(NCC1CN(Cc2ccccc2)CC1)c1ccc(OCCCN2CCOCC2)cc1
# % of correct molecules is 100.00
# O=C(Nc1cccc2c1N1CCCCC1)C1C=CN2C1=NCCc1ccc(Cl)cc1
# % of correct molecules is 100.00
# CC1(C)C2CC1OC1C(=O)OC3CNCCCC3(C)C12
# % of correct molecules is 100.00
# Nc1ncnc2c1ncn2C1OC(CO)C(O)C1O
# % of correct molecules is 100.00
# COc1ccccc1C(=O)Nc1ccc(Br)cc1
# % of correct molecules is 100.00
# Cc1cc(C2CCCO2N=NN(CC2CC2)s2)c(=O)c2ccc(Cl)cc21
# % of correct molecules is 0.00
# Cc1ccc(C2=NNC(c3ccccc3)N(c3ncccn3)C2)nn1
# % of correct molecules is 100.00
# Cc1cc(O)c(C(=O)CC2(O)CCc3cc(Cl)c(Cl)cc3O2)c(=O)[nH]1
# % of correct molecules is 100.00
# O=C(CO)Nc1ccc2c(c1)Cc1c(cnn3-c3ccccc3Cl)n1-2
# % of correct molecules is 0.00
# NCCOc1ccc(N2CCN(Cc3ccc(N)cc3Cl)CC2)cc1
# % of correct molecules is 100.00
# O=C1C(=S)NC(=O)C1=Cc1cn(-c2cncc(Br)c2)nn1
# % of correct molecules is 100.00
# COc1ccc(C(CNC(=O)C(C(=O)Nc2cccc(OC)c2)c2ccc(OC(C)=O)cc2)SC3)cc1
# % of correct molecules is 0.00
# CCc1nnc(CCc2nnc(N)nc2O)cc1C#Cc1ccccc1
# % of correct molecules is 100.00
# Cc1ccc(C=NNC(=N)N)s1
# % of correct molecules is 100.00
# CCCC(C(=O)NCc1cccs1)N1C(=O)C(=C(C)C)NC1C
# % of correct molecules is 100.00
# O=C(CN1C(=O)NC2C=CCC1C2)NS(=O)(=O)C=Cc1ccc2c(c1)OCO2
# % of correct molecules is 100.00
# CC1CCC2C(C)C(COC(c3ccccc3)CCCO2)=C(C(C)C)C1
# % of correct molecules is 100.00
# COc1ccc(Br)cc1-c1ncc(CO)o1
# % of correct molecules is 100.00
# CC(=O)Nc1ccc2c(NN=Cc3cc(OC)ccc3C)noc2c1
# % of correct molecules is 100.00
# Cc1ccnc(NC(=O)c2ccc(C(=O)NCC3CCCO3)cc2)c1
# % of correct molecules is 100.00
# CC(C)(C)CC(=O)C=Cc1ccc(O)c(C=O)c1
# % of correct molecules is 100.00
# c1ccc(Cn2ccnc2-c2ccccc2)cc1
# % of correct molecules is 100.00
# CS(=O)(=O)N1CCN(C)CC1
# % of correct molecules is 100.00
# CN1CCCN(Cc2cccc(Br)c2)CC1
# % of correct molecules is 100.00
# CCOc1ccc(NC(=O)CSc2nnc(CN(CCCn3ccnc3)OC)cc2C)S(=O)(=O)c2ccccc21
# % of correct molecules is 100.00
# COc1ccccc1OC(=O)N1CCC(C)CC1
# % of correct molecules is 100.00
# Cc1cc(Br)cn2c(Cc3ccc(Cl)cc3)nc(N3SCC(C)O3)n12
# % of correct molecules is 0.00
# O=C1C(=O)N=C(N)N=NN1CCCCc1nccs1
# % of correct molecules is 100.00
# O=c1c2c(c(NS(=O)(=O)Nc3ccccc3[N+](=O)[O-])oc2=O)c2ccccc21
# % of correct molecules is 0.00
# COc1ccc(C2=NN(c3ccccc3C)C(=O)c2cnc(N)cc2-c2ccc(OC)cc2)cc1
# % of correct molecules is 0.00
# COc1ccc(CNCc2c[nH]cn2)cc1
# % of correct molecules is 100.00
# Cc1snc(NS(=O)(=O)c2ccccc2SCc2nnc(N3CCOCC3)n2)c1C
# % of correct molecules is 0.00
# CCCN1CCN(S(=O)(=O)c2ccc(C(=N)N)cc2)CC1
# % of correct molecules is 100.00
# N#Cc1ccc(Cl)c(CNc2cc(N3CCOCC3)nc3ccc(-c4ccncc4)nn23)n1
# % of correct molecules is 0.00
# COc1cccc(C=C(CN(C)C(C)(C)C)=NO)c1Nc1ccc(NC(=O)c2ccc(N)c(C(=N)N)c2)cc1
# % of correct molecules is 0.00
# COc1cccc(C(=O)Nc2cnc3ncn(-c3ccccc3)c(=O)c2c1
# % of correct molecules is 0.00
# N#Cc1cc2cc(COc3cccc(CNC(=O)c4ccc5c(Nc6ccc(N(C)c6cc(Cl)cccc6Cl)c5Cl)c44)ccc2O)no1
# % of correct molecules is 0.00
# CCCCC(N=C(O)c1ccncc1)c1ccc(S(N)(=O)=O)cc1
# % of correct molecules is 100.00
# Clc1ccc(CN(CC)Cc2nnc3n2-c2ccc(NC(=O)Nc4ccc(N5CCC(N5CCNCC6)CC5)cc4)s3)cc1Cl
# % of correct molecules is 0.00
# O=c1n(Cc2cccc(N3C(=O)c4ccccc4C3=O)c2)c2ccc(Br)cc2n1Cc1ccc(Cl)cc1
# % of correct molecules is 100.00
# Nc1ncnc2c1c(-c1ccco1)nc2nc(-c3c[nH]c4ccccc14)c(-c1ccccc1)n32
# % of correct molecules is 0.00
# COc1cccc(-c2cc(NC(C)CO)nc(Nc3ccc(Cl)cc3[N+](=O)[O-])c2=O)n1
# % of correct molecules is 0.00
# CCC(C)c1ccc(NC(=O)NC23CC4CC(CC(C4)C2)C3)cc1
# % of correct molecules is 100.00
# Cc1cccc2c(Sc3cccc(Br)c3)c(-c3ccco3)nn12
# % of correct molecules is 100.00
# CC1CCC2C=C(c3nc([N+](=O)[O-])nc(N4CCSC4=O)n3)CC21
# % of correct molecules is 100.00
# CCCCC(CCc1cccc2ccccc12)N(O)C(C)=O)C1OC(OC)OC1=O
# % of correct molecules is 0.00
# CC1NC(=O)CC2ICN(C(=O)C(CC=C(C)C)NC(=O)C3)CC21CC2C
# % of correct molecules is 0.00
# C=C(C)C1OC2OC3(C)CCC3C(C)C(O)C(OC(=O)C(OC)CO)C(C)(O)C12C
# % of correct molecules is 100.00
# COc1ccc(NC(=O)CNC(=O)c2cc(-c3ccc(OCCCCCCC(O)C(=O)O)cc3)c(-c3ccccc3)s2)s1
# % of correct molecules is 100.00
# CCCCc1c(N)n(Cc2ccccc2C)c2ccc(Br)cc12
# % of correct molecules is 100.00
# Clc1ccc2nc(SCC(=O)Nc3cocc(-c4ccc5c(c4)OCO5)n3)sc2c1
# % of correct molecules is 0.00
# Cc1noc(C)c1N(C)c1nc(Nc2ccccc2OCc2ccccc2C2CCCC2)sc1C1=NCC1
# % of correct molecules is 100.00
# O=C(CC12CC3CC(CCC13C(=O)Nc2ccccc12)N1Cc2ccccc2C=O)O1
# % of correct molecules is 0.00
# CCOc1ccc(C(=O)NC(=S)Nc2ccccc2C2=C(O)C(C(=O)C=Cc3ccccc3)OC(=O)C2(C)C)cc1
# % of correct molecules is 100.00
# CCc1sc(NC(=O)C(O)(c2ccccc2)Cc2ccc(Cl)cc2)c2ccccc21
# % of correct molecules is 100.00
# CCS(=O)(=O)Cn1c(=O)n(CCCC2=CC(=O)C(=O)c3ccccc32)c(=O)c2[nH]cnc21
# % of correct molecules is 100.00
# C=CC(=O)NCC1OC(Oc2c(OC)cc(Br)cc2I)c2ncc(C3=CCCCC3)c(=O)n21
# % of correct molecules is 100.00
# Cc1cc(NC(=O)NS(=O)(=O)c2ccc(OCCOC(=S)Nc3ccccc3)cc2)nc(N2CCN(C3CCCCCC3)CC2)n1
# % of correct molecules is 100.00
# Cc1cc(CNC(=O)c2ccc(I)cc2)no1
# % of correct molecules is 100.00
# CCOC(=O)C(Cc1ccccc1)C(=O)NC(C(=O)OCc1ccccc1)C(C)O
# % of correct molecules is 100.00
# CCCCCCCCCCC(=O)OCC(=O)NCCCCCC(C)C
# % of correct molecules is 100.00
# Cc1cc(C(=O)NC(CC(=O)O)c2cnc(N3CCOCC3)n2)ccc1C(=O)OCc1ccccc1
# % of correct molecules is 0.00
# CCN1CCN(C(=O)c2cc3c(cc2C)N(CC(C)C)C3=O)CC1
# % of correct molecules is 100.00
# CC(C)(C)NCc1cn(-c2ccccc2C#N)nc1N
# % of correct molecules is 100.00
# Cn1c2ccc(-c3c(NC(=O)C4CC4)cc(CO[N+](=O)[O-])c3)cc2n2cccc12
# % of correct molecules is 0.00
# Cc1cc(NS(=O)(=O)c2ccc(C)s2)ccc1-c1nccc2cnccc12
# % of correct molecules is 100.00
# O=C(C=Cc1ccc(OCCCCN2CCN(c3ccc4c(c3)OCO5)CCC2)ccn1)NO
# % of correct molecules is 0.00
# CCCCC(=O)C1(c2ccc(-c3ccc(Cl)cc3)cc2)CCN(C(C)=O)CC1
# % of correct molecules is 100.00
# COc1ccc(NC(=O)CBr)cc1-c1ccc(Cl)c(-c2ccccn2)c1
# % of correct molecules is 100.00
# c1ccc([N+](=O)[O-])cc1NC(=O)Nc1ccc(Br)cc1
# % of correct molecules is 100.00
# CC(SCc1ccccc1)c1c(N2CCSC2)sc2c1CCC(CCC)C2
# % of correct molecules is 100.00
# ON=C(C(=O)Nc1ccccc1)Nc1cccc(C2CC3CNCCN23)c1
# % of correct molecules is 100.00
# NCc1ccc(CNC(=O)c2cc(-c3ccccc3N)nc3ccccc23)cc1
# % of correct molecules is 100.00
# O=C(c1ccc(CNC2CCNCC2)n1Cc1cccn1C)n1cc(Cl)nn1
# % of correct molecules is 100.00
# C[N+]12CC=C(CC1(O)C1CCC3(C)C=C1C(O)CC1C3)C(OC)CC1O
# % of correct molecules is 0.00
# CCC12CCC4(C)C(C)=C(S)C(=O)NC13C1(C)OO1
# % of correct molecules is 0.00
# OCC1OC(c2ccccc2)c2ccccc2O1
# % of correct molecules is 100.00
# Cc1ccc(NC(=O)CSc2nnc(-c3ccccc3Cl)o2)cc1
# % of correct molecules is 100.00
# Cc1cc(-n2cccn2)n(CC(C)C)c1CC1CCCC(NC(=O)c2cc3ccccc3[nH]2)C1
# % of correct molecules is 100.00
# COc1cc2ncc(C(=O)NCc3ccccc3)cc2n1
# % of correct molecules is 0.00
# CCCCCCCCCCCCCCCCCOc1ccc(C(=O)N(C)C(=O)N(C)CCO)cc1
# % of correct molecules is 100.00
# S=C(NCc1cccnc1)NCCN1C=C(c2nccnn2)CC1=O
# % of correct molecules is 100.00
# Cc1cccc2nnc(-c3cccs3)n12
# % of correct molecules is 100.00
# O=c1c(Oc2cccc3[nH]c(-c4ccc(Cl)cc4)cc23)c(-c2ccccc2)nn1
# % of correct molecules is 100.00
# COCCCn1c(=O)c2sc3c(c2c(=O)n1CC=Cc1ccccc1)C(=O)CC3
# % of correct molecules is 100.00
# CC(=O)NC(C)CC(=O)Nn1nnc(-c2ccc(-n3cnnn3)cc2)n1
# % of correct molecules is 100.00
# Cc1ccc(NC(=O)Nc2ncsc2N2CCC(c3ccccc3)CC2)nc1
# % of correct molecules is 100.00
# COC(=O)C(N)C(C)CCOS(=O)(=O)c1c(C)cccc1C
# % of correct molecules is 100.00
# CN1Cc2ccc(C#N)nc2NC(=Nc2ccc(N3CCNCC3)cc2)C1=O
# % of correct molecules is 100.00
# Cc1nc(-c2ccc(Cl)cc2Cl)co1
# % of correct molecules is 100.00
# Cc1cccc(-c2nc(NCc3ccnc4cc(Cl)ccc34)ccc2NC(CC(C)C)C(=O)O)c1
# % of correct molecules is 100.00
# O=C1C2=C(CCCC2)C(=O)NC1=S
# % of correct molecules is 100.00
# CN(CCc1ccc(N)cc1-c1ccccc1)CC(=O)NC(C=N)CO)CC(S
# % of correct molecules is 0.00
# OC=CCc1ccc(Cl)cc1Cn1c(=O)c(=NCCCC(=O)N2CCOCC2)c2ccccc2c1Oc1ccccc1
# % of correct molecules is 0.00
# Oc1ccc2c(O)ccc(O)c2n1
# % of correct molecules is 100.00
# Cc1ncc(C)n(CC2CCN(C(=O)c3ccccc3OC)CC2)n1
# % of correct molecules is 0.00
# CC(C)N1CCC2C(C1(c3ccc(Cl)c(Cl)c3)C1c1ccc(Cl)cc1)C2
# ...
# % of correct molecules is 100.00
# COc1cc(OCc2ccc(-c3nnc(S)o3)c2)c2c(C)cc(=O)oc2c1
# % of correct molecules is 0.00
# N#Cc1ccn(CCCOC(=O)C2=CCCCC2)s1
# % of correct molecules is 0.00
# CCN(C(C)=O)N1C(=O)CCC1=CCC=O
# % of correct molecules is 100.00
# Cc1c(CC2CC2)nc(C2CCN(Cc3ccccc3)CC2)nc1OCc1cccc(Cl)c1
# % of correct molecules is 100.00
# CC(C)(O)C(O)C(=O)NC(Cc1ccccc1)C(=O)NCc1ccccc1
# % of correct molecules is 100.00
# COC(=O)c1cc2cc(OCCNC(=O)c3cccc(Br)c3)ccc2o1
# % of correct molecules is 100.00
# COc1ccccc1Nc1nc(N)nc(-c2ccccc2OCC(O)CO)n1
# % of correct molecules is 100.00
# COc1ccc(Cn2c(-c3cc(Cl)ccc3Cl)nc3c(S(=O)(=O)c4ccco4)c4ccccc4sc3n2)cc1
# % of correct molecules is 100.00
# CC(CC(=O)NS(=O)(=O)c1ccc2ccccc2c1)c1ccccc1
# % of correct molecules is 100.00
# C=C(C)C(OC(N)=O)C(=O)NC(CO)C(=O)c1nc2ccccc2n1CCN1C(=O)CCC1C
# % of correct molecules is 100.00
# CC(C)CNc1cc(-c2n[nH]c3ccc(Oc4c(O)cc(OC)cc4Br)cc23)nn1
# % of correct molecules is 0.00
# Nc1cccc2c1C(CN1CCCC1)N(Cc1ccc(Cl)cc1)C2=O
# % of correct molecules is 100.00
# N#Cc1c(NC(=O)NCc2ccccn2)oc2ccccc12
# % of correct molecules is 100.00
# NC(=O)c1cc(NC(=O)Nc2ccc(C(=N)N)cc2)ccc1OCc1ccc(-n2ccnc2)cc1
# % of correct molecules is 100.00
# C=CCNC(=O)CCCc1ccc(OCC(=O)NC2CCCC2)cc1
# % of correct molecules is 100.00
# Cc1ccc(C(CCN2CCOCC2)c2ccc(Cl)cc2)cc1C
# % of correct molecules is 100.00
# CC(C)(C)c1ccc(N)cc1
# % of correct molecules is 100.00
# COc1cc(C(=O)NC=C2C(=O)Nc3ccc(Cl)cc32)ccc1Nc1c(Nc2ccc3ccccc3c3nc(C)on2)c2c3c(nc4ccccc41)Oc3cc(OC)ccc4C3=O)cc(OCCN1CCOCC1
# % of correct molecules is 0.00
# S=C(NCC(O)CNC(=O)c1ccccc1)NN=Cc1cccnc1
# % of correct molecules is 100.00
# OC(=Nc1ccc(Cl)cc1O)C1CCN2CCC1CC2
# % of correct molecules is 100.00
# N=C(N)NCCCn1c(-c2ccccc2)[nH]c2ncc(Cl)c21
# % of correct molecules is 0.00
# CCN1CCN(CCC2CCOCC2)CC1
# % of correct molecules is 100.00
# O=C(O)c1cccc(Nc2nc(-c3cccc(Cl)c3)c(-c3ccnc(N4CCC4)c3)nn2)n1
# % of correct molecules is 100.00
# CCCCCCCCNC(=O)C1=C(C)N=C(N)Oc2ccc(Cl)cc21
# % of correct molecules is 100.00
# Nc1ccc2c3c(c1c(c1)CN(C(=O)NC1CCCC1)Cc1ccccc1-3)CCCC2
# % of correct molecules is 0.00
# CCCCCCCPn1nc(-c2cccc(CN(CC)(C)C)c2)c(=O)n(CCCCCCCC(C)C)c1=O
# % of correct molecules is 0.00
# COC(=O)c1cccs1
# % of correct molecules is 100.00
# NC(=O)CCn1ccn(C2CCCCN2C(=O)CCCc2c[nH]cn2)c1=O
# % of correct molecules is 100.00
# Nc1ncnc2c1nc(N)c2ccc(O)cc12
# % of correct molecules is 0.00
# CCOc1ccc(NS(=O)(=O)c2ccc(S(=O)(=O)NCCc3ccccc3OCCS(C)(=O)=O)cc2)cc1
# % of correct molecules is 100.00
# CC=C1C(=O)OC2CC(O)C3(C)C(O)CC=C3CC3(C)C(=O)C12C
# % of correct molecules is 0.00
# O=C(C1CCCN1C(=O)NCc1ccccc1)Nc1ccc2[nH]c(C3CCC3)sc2c1
# % of correct molecules is 0.00
# COC1CN(C(=O)Nc2ccc(NC(C)=O)cc2)C2CCC(C1)N2C
# % of correct molecules is 100.00
# CCOC(=O)C(C)Oc1ccc(C(=O)NC(CCc2ccccc2)C(=O)Nc2ccc(OC)cc2)cc1
# % of correct molecules is 100.00
# COCCn1ncc2c1CCN(C(=O)c1cc(-c3ccccc3NC(=O)C3CC3)oc(n1)CN(C)CC1=Cc2ccccc2CC1=O
# % of correct molecules is 0.00
# Cc1ncc(-c2cc(C3OC(CO)C(O)C(O)C3O)c(COC(=O)c3cccc(Br)c3)n2-c2nonc2N)cc1C
# % of correct molecules is 100.00
# Cc1ccc(C(=O)NS(=O)(=O)N2CCN(C(=O)C(C)(C)C)CC2)nc1-c1cccc(Br)c1
# % of correct molecules is 100.00
# CC(=O)c1ccc(C=NNC(=O)c2ccc(OCC3CC3)nc2)cc1
# % of correct molecules is 100.00
# COc1cc(-c2nc(C)c(COC(=O)c3ccc4c(c3)oc3c5ccc(NC(=O)C)ccc4c3)c2C#N)ccc1OC
# % of correct molecules is 0.00
# CC(=O)c1c(OCCc2ccccc2OCc2ccccc2)oc2ccc(OCC(=O)N(C)c3ccccc3)cc2c1=O
# % of correct molecules is 100.00
# CCCCCC=CC=CC(C)C
# % of correct molecules is 100.00
# COc1ccc(C(=O)NCc2c(C)noc2-c2cc(OC)c(OC)c(OC)c2)cc1
# % of correct molecules is 100.00
# Cc1oc(-c2ccccc2-n2c(C)nc3ccccn32)cn1
# % of correct molecules is 0.00
# O=Cc1ccc2c(c1)C(N1CCOCC1)c1ccccc1S2
# % of correct molecules is 100.00
# CC(C)c1nc(C(N)=S)nc2c1c(=O)n(Cc1ccc(Cl)cc1)n2C
# % of correct molecules is 100.00
# Cc1cccc(NS(=O)(=O)c2ccc(NC(=O)Nc3ccc(Oc4ccc(C)nc4C)cc3)cc2)c1
# % of correct molecules is 100.00
# COc1ccc(-c2c(C3CN5CCC3COC(=O)C4Cc4ccc5ccccc5n4)ncnc3Oc3ccc(OC)cc3C2=O)c(OC)c1
# % of correct molecules is 0.00
# CCNC(=O)Cc1cc(-c2ccccc2OC)n2sc(Cc3ccccc3)c(=O)c2c1
# % of correct molecules is 0.00
# c1cccc(NC(=S)N2CCNCC2)c1
# % of correct molecules is 100.00
# O=C(O)C(Cc1ccc(Br)cc1)=C1OC(=O)NC1=O
# % of correct molecules is 100.00
# OC(c1ccccc1[N+](=O)[O-])N1CCCC1
# % of correct molecules is 100.00
# CC[N+](CC)(CC#C)CCCCC[Se]c1ccc(-c2ccccc2)cc1
# % of correct molecules is 100.00
# CC(C)c1occ(-c2ccc(OCCN3CCCC3)cc2)n1
# % of correct molecules is 100.00
# Cc1nn(-c2ccccc2)c2ccccc12
# % of correct molecules is 100.00
# CCNc1ncnc2c1c(=O)n(-c1ncc(-c3ccccc3Br)cc1C(C)C)CC(=O)N2C
# % of correct molecules is 100.00
# CCOC(=O)c1c(SCc2ccc(C(=O)OC)cc2)c(=O)[nH]c(=O)n1Cc1ccc(-c2cccc3c2C(=O)NC3=O)cc1
# % of correct molecules is 100.00
# Cc1cccn(CCNC(=O)C(CCCC(=O)NC(C)(C)C)C(OC)C(=O)Nc2cc(C)nc(-c3ccncc3)n2)c1
# % of correct molecules is 0.00
# NS(=O)(=O)c1ccnc(Nc2nc(NCc3ccccc3)cs2)c1
# % of correct molecules is 100.00
# COc1ccccc1NC(=O)c1c(C)n(Cc2ccccc2)c2ccccc12
# % of correct molecules is 100.00
# Cn1c(O)nc2c1nc(SCc1ccccc1)n2CCCCOP(n1c2ccccc1Cl)C2
# % of correct molecules is 100.00
# CC1=CCCC2(C)C1(CC)CC2
# % of correct molecules is 100.00
# Cc1ccco1
# % of correct molecules is 100.00
# N#Cc1ccc(-c2c3c(nc4ccccc23)CCN4CCCNC3=O)cc1
# % of correct molecules is 0.00
# COc1ccc(-n2c(C(=O)NO)cc3cc(Sc4ccc(OC)cc4)ccc23)cc1
# % of correct molecules is 100.00
# Cc1cc(OCC2COc3nc(N)nc(N)c3-2)ccc1C1CCC1
# % of correct molecules is 100.00
# CCSSCCCCC=CCCC=CC(O)C(N)CC(=O)O)C(O)CC(C)P(=O)(OCCCCC(C)n1cc(C)n(C)c1=O)C(C)(C)C
# % of correct molecules is 0.00
# COc1cc(NC(C)=O)ccc1C(=O)NN=Cc1ccc(O)c([N+](=O)[O-])c1
# % of correct molecules is 100.00
# COc1ccc(NCC(O)c2ncc(S(=O)(=O)N3CCc4ccccc4C3)cc2Cl)cn1
# % of correct molecules is 100.00
# CCOCc1c(NC(=O)c2ncc(-c3ccc(Cl)cc3)s2)nnc1-c1ccco1
# % of correct molecules is 0.00
# CC1(C)CCC23CC2C1(C)CCC2(CC1OCC(O)C13)OO1
# % of correct molecules is 0.00
# O=c1c2cn[nH]cc2[nH]1
# % of correct molecules is 0.00
# Cc1cc(C)nc(Sn2nnc3ccccc3c2=O)c1C
# % of correct molecules is 100.00
# O=C1Nc2cccc3c2C1=NCc1ccccc1C2=O
# % of correct molecules is 0.00
# CC(N(Cc1cccnc1)c1ccccc1)C(=O)N1CCc2c(CCN(C)Cc3ccccc3Cl)cc(C=Cc3ccccc3)c2CC1Br
# % of correct molecules is 0.00
# CC(=O)NCc1ccc(-c2ccc(Cl)cc2)cc1
# % of correct molecules is 100.00
# CC(C)(C)C[N+](=O)[O-]
# % of correct molecules is 100.00
# COC(=O)c1ccc2c(c1)S(=O)(=O)N2c1ccc(cc1)N(C)CC2O
# % of correct molecules is 0.00
# CCC(C)c1ccc(NC(=O)CS(=O)(=O)c2ccc(OCCN3CCCCC3)cn2)cc1
# % of correct molecules is 100.00
# Cc1ccc2c(Nc3cccc4cc(C#N)ccc34)c3ccccc3nc2c1
# % of correct molecules is 100.00
# CCN1CCN(C2CCN(c3ccccc3)CC2)CC1
# % of correct molecules is 100.00
# C=C1C(=O)C23CCC4C(C)(C)CCC4(C)C2CC12C(=O)O
# % of correct molecules is 0.00
# c1cc(NCc2cccc3ccccc23)c2ccccc2n1
# % of correct molecules is 100.00
# COc1cccc(Cn2c(=S)n(CCCCCCN3CCN(C)CC3)c(=O)n2C)c1
# % of correct molecules is 100.00
# CCN(CC)C(=O)c1cc(O)cc(NC(=O)CNC(=O)c2ccc(NC(=O)CC)cc2)c1
# % of correct molecules is 100.00
# c1ccc(Sc2ccc(CC(Nc3cccnc3)COCc3ccccc3)cc2)cc1
# % of correct molecules is 100.00
# Cc1cc(NC=C2C(=O)N(CO)(c3ccccc3Cl)CC2=O)n(C)c1
# % of correct molecules is 0.00
# Cc1noc2c(OCCC(=O)O)cccc12
# % of correct molecules is 100.00
# Cc1nnc(NC(=O)CSc2nsc3n2CCCC3)s1
# % of correct molecules is 0.00
# COc1ccccc1C(=O)N1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)NC(=O)C1
# % of correct molecules is 100.00
# CCC(=O)N1CCN(S(=O)(=O)N2CCOCC2)CC1=O
# % of correct molecules is 100.00
# COc1ccc(-c2ccc3ncc(-c4ccc(CCN5CCCC5)nn4)cc3c2)c2ccc(C(=N)N)cc12
# % of correct molecules is 100.00
# Cc1cnc(OCC(=O)N2CCN(S(=O)(=O)C3CCN(S(C)(=O)=O)CC3)CC2)c(C)c1
# % of correct molecules is 100.00
# Cc1sc(-c2nc(CN3CCN(C4CCC4CC3)C(C)O4)ncc2Cl)cc1Br
# % of correct molecules is 0.00
# O=C(O)c1ccc(C(c2sc(-c3cccc(Br)c3)cc2O)c2ccc(C(=N)N)cc2)cc1
# % of correct molecules is 100.00
# COc1cc(C=C2CCCC2=O)cc(OCc2cc(O)c(OC)c(OC)c2)c1
# % of correct molecules is 100.00
# C#Cc1c[nH]c2c(C3CNCCN3C)nnc12
# % of correct molecules is 0.00
# Cc1ccc2c(CC(=O)O)nc(NCCCCCCCNCc3cccc(C)c3)nc2c1
# % of correct molecules is 100.00
# CCC(CC)CC(=O)N1CCC2(c3ccccc3)CC=C1C(N2C(=O)CCc1ccccc1)C2
# % of correct molecules is 0.00
# Cc1cc2nc3ccccn3c2n2c1nc1ncccc1c2=O
# % of correct molecules is 100.00
# c1ccc(CNCC2Cn2cccc2)cc1NC(=O)c1cc(Br)ccc1OCc1ccccc1
# % of correct molecules is 0.00
# Cc1ccc(C2NC(N)=CC(=O)C2=NNC(C)c2ccc(C)cc2)cc1
# % of correct molecules is 100.00
# O=c1c(Oc2ccccc2)sc(NN=Cc2ccc(Br)c(Cl)c2)n1
# % of correct molecules is 0.00
# Cc1cc(C)c(NC(=O)CCN2CCN(c3nc(-c4cccc(O)c4)cs4)CC2)nn1
# % of correct molecules is 0.00
# Nc1non2cccc1c2C=C(c1ccccc1)c1ccccc1
# % of correct molecules is 0.00
# COc1ccc(CNC(=O)c2[nH]n3c(=N)cc(C)nc23)c(OC)c1
# % of correct molecules is 0.00
# CCc1ccc(NC(=O)CCn2c(-c3ccco3)nc3cc(Cl)ccc32)cc1
# % of correct molecules is 100.00
# Cc1nnc2n1Cc1c(-c3ccc(CN4CCOCC4)cc3)cccc1-c1ccccc12
# % of correct molecules is 100.00
# COc1ccc2c(=O)cc(-c3ccccc3OCC(C)=O)cc(O)c2c1C
# % of correct molecules is 100.00
# Cc1cc(O)nc(SCc2ccc(OCC(=O)O)cc2OC)n1
# % of correct molecules is 100.00
# CCC(=O)NCCCCC=CC(=O)O
# % of correct molecules is 100.00
# CCCCCCCCCCNC(=O)C1CCCN1c1ccccc1
# % of correct molecules is 100.00
# NCC1OC(n2cnc3c(NC4CNS(=O)(=O)NC(=O)NC4CC4)nc(N)nc32)C(O)C1O
# % of correct molecules is 0.00
# CC1=C(OCCO)SCC=C(CO)C1
# % of correct molecules is 100.00
# Cc1n[nH]c2cc(-c3ccc4nc(N5CC5(C)CC5)c(-c4ccccc4)cc3)nn12
# % of correct molecules is 0.00
# COc1ccc(C(=O)Nc2ccc(NC(=O)C(C)C)c(C#N)c2)cc1
# % of correct molecules is 100.00
# O=c1ccc2n3cccn3c2cn1Sc1ccccc1
# % of correct molecules is 0.00
# NCC(=O)Nc1nc2sccc2[nH]1
# % of correct molecules is 100.00
# N=C(N)NCCCC(NC(=O)c1ccc(NC(=O)OCc2ccc3c(c2)CCC3)cc1)CC(=O)O
# % of correct molecules is 100.00
# O=P(O)(O)C(O)C(NCCCCCCCCCCCNS(C)(=O)=O)OP(=O)(O)OP(=O)(O)OP(=O)(O)OP(=O)(O)O)C(=O)Nc1ccccc1
# % of correct molecules is 0.00
# NC(C=Nc1ccc(Cl)cc1)C(N)=NC(C)=O
# % of correct molecules is 100.00
# Cc1cc(S(=O)(=O)NC2CCCC2)cc(N2CCc3c(sc(Cc4ccccc4Cl)c3C2=O)CCCCC)c1
# % of correct molecules is 100.00
# Cc1ccc(-c2cc(S(=O)(=O)N(CC(C)C)CC(O)c3ccccc3)cs2)cc1
# % of correct molecules is 100.00
# CN(CC#CC#Cc1ccc(NCc2cccc(C(=O)O)c2)cc1)CC(=O)N1CCN(c2ccc(C(=O)O)cc2)CC1
# % of correct molecules is 100.00
# Nc1ncc(-c2cnc(C3CCc3nnc4cccnc43)nn2)o1
# % of correct molecules is 0.00
# CCCNc1nc(O)c(CC2CCCN2C(=O)c2cccc(Br)c2C)s1
# % of correct molecules is 100.00
# Cc1ccc(NC(=O)NC2CCc3ccccc3N2)cc1
# % of correct molecules is 100.00
# O=c1nc(N2CCN(C3CCCO3)CC2)c(Br)s1
# % of correct molecules is 0.00
# O=C(NC(=S)NCCc1ccccc1)c1ccccc1
# % of correct molecules is 100.00
# CCc1cccc(-c2nnc(N3CCCC3)n2)c1
# % of correct molecules is 0.00
# CN(C)CC1COc2cc(OCc3ccccc3Br)ccc21
# % of correct molecules is 100.00
# COc1cc(OC)c2c(=O)c(-c3c(Cl)cc(Cl)cc3O)sc2cc1OCCCN1CC2CNCC2C1
# % of correct molecules is 0.00
# CCOC(=O)c1c(NC(C)=O)sc2nc(-c3ccc(Cl)cc3)c(-c3ccc(Cl)cc3)n12
# % of correct molecules is 100.00
# COc1ccccc1Cn1c(=O)c2sccc2nc2c(Cl)cccc21
# % of correct molecules is 0.00
# CN(CC1CCN(Cc2ccccc2OCCCCCO)C1=S)c1ccccc1Cl
# % of correct molecules is 100.00
# O=C1C2([n+]([O-])CCc3[nH]c4ccc(-c5cnc(=NO)nn6)cc4CCC3C1(O)C3
# % of correct molecules is 0.00
# CC1CCCC(O)(CCC(=O)O)CC1
# % of correct molecules is 100.00
# CN1Cc2cccc3c(C(=O)c4cc5ccccc5[nH]c5c4)cc(-c4ccc(C#N)cc3)c21
# % of correct molecules is 0.00
# Nc1ncc(-c2cccc(OC3CCCN3CCc3cc[ne]c3)c2)nc1Nc1cccc(C2CCNCC2)c1
# % of correct molecules is 0.00
# Cc1cc(O)c2c(=O)c3c(n(Cc3cccs3)C(C)C(=O)Nc3ccccc3)c2n1
# % of correct molecules is 0.00
# CCCCCCn1cccc1C(=O)N1CCCC(CN(CCCC)C(=O)O)CC1
# % of correct molecules is 100.00
# CC(C)c1ccc(Cl)c(Nc2nsnc2-c2ccc(S(=O)(=O)N3CCOCC3)cc2)n1
# % of correct molecules is 100.00
# COc1ccc(CNC(=O)CN(C)Cc2csc(-c3ccc(C)c([N+](=O)[O-])c3)c2-c2ccc(OC)cc2)c(OC)c1
# % of correct molecules is 100.00
# COc1ccc(S(=O)(=O)ON=C(N)N2CCOCC2)cc1
# % of correct molecules is 100.00
# Cc1cc[n+](C[n+]2ccc(S(=O)(=O)NCCCCCCCCCCCCCCCCCCCCCCNCCCCCC(=O)O)cc2O)cc1
# % of correct molecules is 100.00
# O=C(O)C=CC=CCCCCc1ccccc1
# % of correct molecules is 100.00
# CCOc1cccc(OCC(=O)C(C)CCNC(=O)NC(Cc2ccccc2)Cc2ccc(C(C)C)c(OC)c2)C(=O)NNC(=O)COc2ccccc2N)c1
# % of correct molecules is 0.00
# CCN1C(=O)c2ccccc2C2(CCN(C(=O)C(CC(=O)NN=C(C)C)CC2=O)C)O1
# % of correct molecules is 100.00
# Cc1ccc(CNC(=O)c2ccc(S(N)(=O)=O)c(Cc3ccc4nccnc4c3)c2)cc1
# % of correct molecules is 100.00
# O=C(Cn1c(=O)oc2cc(Br)ccc21)NC1CCCCC1
# % of correct molecules is 100.00
# CCC1CC2C(CNC3(C)C)CCN(C)CC21
# % of correct molecules is 0.00
# Cc1ccc([Si](C)(C)C(=O)N2CC3CCC2N3C)cc1
# % of correct molecules is 100.00
# CCC(CC(NC(C)=O)C(=O)NCC1CCCN1C(=O)C(Cc1ccccc1)NC(=O)OCc1ccccc1)OC(=O)c1cccs1
# % of correct molecules is 100.00
# Cc1cc(C)c(S(=O)(=O)NCC2CCCNCC2CN2CCC(O)CC2)nn1
# % of correct molecules is 100.00
# O=C1NCC2(CCCC1)C(n1ccnc1)c1ccncc1N=C2c1ccc(Cl)cc1
# % of correct molecules is 100.00
# Cc1cc(NCCCCCCN2CCC(S(C)(=O)=O)CC2)nc(N(C)C)c1Br
# % of correct molecules is 100.00
# CC1CC(=O)NC2(CCC1)OP(=O)(O)OC2Cn1c2ccccc2c(=O)n(NC(=O)OC(CC(=O)NCC(=O)c3ccc(Cl)cc3)C(=O)C(C)(C)C)c2c1=O
# % of correct molecules is 0.00
# CC(C)C(=O)NN(C(=O)c1[nH]c(Cl)c(Cl)n1)NCC=C(N)C(=O)c1nccs1
# % of correct molecules is 100.00
# CC(=CCc1ccc(OC)cc1)OC(=O)c1ccc(-c2ccccc2)cc1
# % of correct molecules is 100.00
# COc1ccccc1-c1sccc1C(c1ccccc1)N(c1ccccc1O)S(=O)(=O)c1ccccc1
# % of correct molecules is 100.00
# COc1ccc(C(=O)NCCCCCCn2cc(C)s2)cc1
# % of correct molecules is 100.00
# NC(=O)Cc1c(C(=O)NO)c(Cn2cccn2)oc(=O)c1CCCCN1CCN(c2ccccc21)c(=O)[nH]c1=O
# % of correct molecules is 0.00
# O=C(O)CC(=O)Nc1nc(-c2cccnc2)cs1
# % of correct molecules is 100.00
# Cc1onnc1C1CCN=N1
# % of correct molecules is 100.00
# O=C(NCc1ccsc1)c1cccc(Nc2ccncc2)c1
# % of correct molecules is 100.00
# O=c1cc[nH]c1CCc1cc(-c2ccccc2)ccn1
# % of correct molecules is 0.00
# C1=NCC2CC1C(c1ccc(-c3cccnc3)cc1)N(CCC1CC1)C2
# % of correct molecules is 100.00
# CC1(COCCCO)CCC2(C)C3=C(CC4C)C(=O)N(C)C(C(=O)c4ccccc4)C12C
# % of correct molecules is 0.00
# c1cc(-c2ccc(-c3ccccc3Cl)nn2)ccc1O
# % of correct molecules is 100.00
# CCN1CCN(c2ccc(SCC(=O)NCC(=O)N3CCOCC3)cc2)CC1
# % of correct molecules is 100.00
# CC1CC(C)CC(N=C(O)c2cccc(N(CCC(=O)O)CNC(=O)C3CCCO3)c2)N1
# % of correct molecules is 100.00
# CC(=O)OC1C=CCC2C(=CC=C3CC(O)C(O)C3O)=CCC(O)C2CC1
# % of correct molecules is 0.00
# O=C(O)C(=O)NCCCCCC(=O)Nc1cccc(S(=O)(=O)Nc2ccc(Br)cc2Cl)c1
# % of correct molecules is 100.00
# CCCCCC=C(C)C(O)C=CC=CCCCC(C)C
# % of correct molecules is 100.00
# Cc1cccc2nc(NCc3c(C)c(CN(C)C)ccc3CCNC(=O)Nc3ccnc(C)c3)nc12
# % of correct molecules is 0.00
# CCc1ccc(CCNS(=O)(=O)c2ccc3c(c2)OCO3)cc1
# % of correct molecules is 100.00
# CCOC(=O)Cc1ccc(S(=O)(=O)Nc2ccc(N3CCc4ccccc4C3)cc2)cc1
# % of correct molecules is 100.00
# CCOCCCNC(=O)C(C)NC(=S)NCCc1ccc(OC)c(OC)c1
# % of correct molecules is 100.00
# Cc1cc(-c2nnc(SCC(=O)NC(C)Cc3ccoc3)n2-c2ccccc2)cc(OC)c1OC
# % of correct molecules is 100.00
# O=S(=O)(NOC(=O)c1cc2ccccc2s1)c1ccc2c(O)cccc2c1
# % of correct molecules is 100.00
# COC(=O)C(CCCN=C(N)N)C1CCC2C3CCC4(C)C(C(C)C)CCCC41C
# % of correct molecules is 0.00
# Cc1nc2ccc3ccc(=O)n(CC(=O)O)c3n2c1N(c1ccccc1)c1ccccc1
# % of correct molecules is 100.00
# Cc1cc2scc(CC)c2c(NN=Cc2ccc(-c3ccncc3Cl)cc2)o1
# % of correct molecules is 0.00
# CC(C)=CC1(C)CCCOC1=O
# % of correct molecules is 100.00
# CCCc1cnn(CC2=CCCC2)c1[N+](=O)[O-]
# % of correct molecules is 100.00
# CCNc1ccc(Cn2ccc(C(=O)c3ccccc3OCC(=O)Nc3sccc3S)cc2CC)cc1
# % of correct molecules is 0.00
# O=C1C2C3C=CC(C3CC3)C2C(c2ccc(Cl)cc2)S1
# % of correct molecules is 0.00
# COc1cc2cc(-c3nc4ccccc4-c3nnn3CCCN(C)C)oc2cc1OC
# % of correct molecules is 0.00
# Cc1cc(SCc2ccc(CN3CCc4ccccc4C3)s2)cc2c1OC(C)(C)C2
# % of correct molecules is 100.00
# CCC(Sc1cnc(Cn2c(N)nc3c(NCc4ccccc4O)nccn23)c(C)c1)c1ccccc1
# % of correct molecules is 0.00
# Cc1ccccc1OCC(=O)Nc1ccccc1
# % of correct molecules is 100.00
# COc1cc(Cl)c(S(=O)(=O)N(C)CC2CCN(Cc3ccco3)CC2)cc1
# % of correct molecules is 100.00
# CCOC(=O)Nc1nc(CNCCc2ccccc2)cs1
# % of correct molecules is 100.00
# CN(C(=O)Cc1ccc(S(=O)(=O)N2CCCCCCCC2)cc1)c1ccccc1)C1CC1
# % of correct molecules is 0.00
# COc1ccc(CC2CN(c3ccc(N)cc3)CCN(S(=O)(=O)c3ccccc3)C2=O)cc1
# % of correct molecules is 100.00
# CCC(C)(C)C(=O)NC(Cc1ccc(OCC(O)C(N)CCCCN(C)Cc2ccc(NS(C)(=O)=O)cc2)cc1)c1ccc(C)cc1
# % of correct molecules is 100.00
# COc1ccc(NCCN(C)C)cc1
# % of correct molecules is 100.00
# COc1cccc(NC(=O)CSC(OCC2Cc3ccccc3o2)C2c3ccc(O)cc3Sc3ccccc32)c1
# % of correct molecules is 100.00
# COc1cc(C=C2SC(=S)N((Cc3ccc(Br)cc3)C2=O)S(=O)(=O)c2ccc(Br)cc2)cc(OC)c1OC
# % of correct molecules is 0.00
# COc1cc(C2c3cc4c(cc3OC(C)=CCC3C4OC(CO)C(O)CC34)OCO2)c(OC)cc1OC
# % of correct molecules is 0.00
# O=C(NCCCCCNC(=O)c1ccccc1Oc1ccccc1)c1ccccc1
# % of correct molecules is 100.00

# %% [markdown]
# #Valid molecules filtering

# %%
import re

input_file = '/content/samples_file.txt'
output_file = 'correct of 20k samples.txt'
target_phrase = '% of correct molecules is 100.00'

# Open the input file for reading
with open(input_file, 'r') as file:
    lines = file.readlines()

# Extract the molecules above the target phrase
correct_molecules = []
for i in range(1, len(lines)):
    line = lines[i].strip()
    if line.startswith(target_phrase):
        molecule = lines[i - 1].strip()
        correct_molecules.append(molecule)

# Create a new file with the correct molecules
with open(output_file, 'w') as file:
    file.write('\n'.join(correct_molecules))

# %% [markdown]
# <h2 style="color:rgb(0,120,170)">Fréchet ChemNet Distance (FCD)</h2>

# %%
# Load ChemNet model
model = load_ref_model()

# %% [markdown]
# Now we can load some generated SMILES strings and calculate the FCD between two smaller subsets sampled from this set. The FCD calculates the distance from a set of `real` samples to a set of `generated` samples. In this first step we just assume that the first set we sample are the `real` samples and the second one the `generated` samples.

# %%
# Load generated molecules from an input file, which contains one generated SMILES per line
gen_mol_file = "/content/correct of 20k samples.txt"
gen_mol = pd.read_csv(gen_mol_file,header=None)[0] 

# Sample two subsets, treat one as "real" SMILES and the other as "generated" SMILES for now
smiles_real = np.random.choice(gen_mol, 8500, replace=False)
smiles_gen = np.random.choice(gen_mol, 8500, replace=False)

# get canonical smiles and filter invalid ones
smiles_real_can = [w for w in canonical_smiles(smiles_real) if w is not None]
smiles_gen_can = [w for w in canonical_smiles(smiles_gen) if w is not None]

# %%
fcd_value = get_fcd(smiles_real_can, smiles_gen_can, model=model)
print('FCD: ', fcd_value)
# Out:
# FCD:  0.17342240055781133

# %% [markdown]
# To show that canonicalization is important, let's see what happens if we don't canonicalize our generated molecules.

# %%
fcd_value = get_fcd(smiles_real_can, smiles_gen, model=model)
print('FCD: ', fcd_value)
# Out:
# FCD:  0.19146534035552065

# %% [markdown]
# <h1 style="color:rgb(0,120,170)">Challenge Server Evaluation</h1>
#
# For the molecule generation exercise you need to submit a set of at least 10000 SMILES strings generated by a model you trained.

# %%
# Load sample submission
gen_mol_file = "/content/correct of 20k samples.txt"
smiles_gen = pd.read_csv(gen_mol_file, header=None)[0].iloc[:10000] 

# get canonical smiles and filter invalid ones
smiles_gen_can = [w for w in canonical_smiles(smiles_gen) if w is not None]

# %%
# Calculate statistics for the sample submission
act_gen = get_predictions(model, smiles_gen_can)
mu_gen = np.mean(act_gen, axis=0)
sigma_gen = np.cov(act_gen.T)

# Load precomputed test mean and covariance
with open("/content/test_stats.p", 'rb') as f:
    mu_test, sigma_test = pickle.load(f)

# %% [markdown]
# Now we can calculate the FCD between the sample submission and real molecules.

# %%
fcd_value = calculate_frechet_distance(
        mu1=mu_gen,
        mu2=mu_test,
        sigma1=sigma_gen,
        sigma2=sigma_test)
print('FCD: ', fcd_value)
# Out:
# FCD:  1.9756214127676799

# %% [markdown]
# <h2 style="color:rgb(0,120,170)">Validity</h2>

# %% [markdown]
# Another metric we can calculate for a submission is the ratio of valid SMILES strings.

# %%
validity = len(smiles_gen_can) / len(smiles_gen)
print("Validity: ", validity)
# Out:
# Validity:  1.0

# %% [markdown]
# <h2 style="color:rgb(0,120,170)">Uniqueness</h2>

# %% [markdown]
# We can also calculate the ratio of unique molecules generated by the model. If the model "collapses" and just generates the same valid molecule over and over we would see that in this metric.

# %%
smiles_unique = set(smiles_gen_can)
uniqueness = len(smiles_unique) / len(smiles_gen)
print("Uniqueness: ", uniqueness)
# Out:
# Uniqueness:  0.999

# %% [markdown]
# <h2 style="color:rgb(0,120,170)">Novelty</h2>

# %% [markdown]
# Lastly, we can check if the generated molecules are indeed "new", or novel, or if the model copied molecules from the training set by comparing the generated molecules to the molecules in the training set.

# %%
# load training set for novelty
with open("/content/smiles_train-2.txt") as f:
    smiles_train = {s for s in f.read().split() if s}
    
smiles_novel = smiles_unique - smiles_train
novelty = len(smiles_novel) / len(smiles_gen)
print("Novelty: ", novelty)
# Out:
# Novelty:  0.9839
